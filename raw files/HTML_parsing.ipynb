# %%
# For getting zip files
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# For unzipping files
# !unzip 41.zip
# !unzip "/content/gdrive/MyDrive/Akib Bruh Mind Seer/Colab Files/41.zip" -d "/content/users"
# !unzip "/content/gdrive/MyDrive/Akib Bruh Mind Seer/Colab Files/Subjects_with_HTML_files.zip" -d "/content/users"
# Out:
# Archive:  /content/gdrive/MyDrive/Akib Bruh Mind Seer/Colab Files/Subjects_with_HTML_files.zip
# replace /content/users/50/pages/no-data.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# Importing BeautifulSoup and 
# it is in the bs4 module
from bs4 import * 
import codecs
import json
import os

# %%
## For traversing all user folders
rootdir = "/content/users"
users_list = []

for (root,dirs,files) in os.walk(rootdir):
    print (root)
    print (dirs)
    print (files)
    print ('--------------------------------')
    users_list = dirs
    break # USE THIS FOR ONLY TRAVERSING LEVEL 1 so no recursiveness
# Out:
# /content/users
# ['41', '24', '90', '50', '57', '64', '102', '89']
# []
# --------------------------------

# %%
print(users_list)
# Out:
# ['41', '24', '90', '50', '57', '64', '102', '89']

# %%
## Test code for appending user id to directory
# for i in users_list:
#   comments_filedir = f"/content/{i}/comments/comments.html"
#   print(comments_filedir)

# %% [markdown]
# Comments Scraper

# %%
for user in users_list: # goes through each user in the folder
  comments_filedir = f"/content/users/{user}/comments/comments.html"

  # Opening the html file. If the file
  # is present in different location, 
  # exact location need to be mentioned
  HTMLFileToBeOpened = codecs.open(comments_filedir, "r", "utf-8") # use codecs.open to open html files!
    
  # Reading the file and storing in a variable
  contents = HTMLFileToBeOpened.read()
    
  # Creating a BeautifulSoup object and
  # specifying the parser 
  soup = BeautifulSoup(contents, 'lxml')


  # comments_dict = {'comments':[], 'timestamp':[]}
  comments_list = []

  ### OLD METHOD
  # USE div.class.class for multiple classes
  # comments_div = 'div._2pin'
  # timestamp_div = 'div._3-94'

  # for text in soup.select(comments_div):
  #     # print(text.string)
  #     comments_dict['comments'].append(text.string)

  # for timestamp in soup.select(timestamp_div):
  #     # print(timestamp.string)
  #     comments_dict['timestamp'].append(timestamp.string)

  # print(comments_dict)

  ### Remove Group Span tags. Doesnt work but keep as useful
  # span_tag = soup.span
  # soup = span_tag.clear()
  # soup = soup.find('div', class_="_3-95").decompose()

  ### This Works. Above one doesnt
  # For Removing Group Names 
  for span in soup("span"):
    span.clear()
  for div in soup.find_all("div", {'class':'_3-95'}): 
      children = div.findChildren("div", recursive=False)
      for child in children:
        for child_div in child.find_all("div", {'class':'_3-95'}):
          child_div.clear()
        # print(child)
      



  # NEW METHOD
  for content in soup.find_all("div", class_="pam"): # content div of each comment
      # print(content,'\n')
      content_dict = {} # create a dictionary for each comment section
      content_dict['user'] = user # create 41 as user id
      # for comment in content.find_all('div', attrs={'class': '_2pin'}): # This loop checks text inside div 
      #   print(comment.get_text)
      # content_dict['comment'] = content.find_all("div").get_text() if content.find("div", class_="_2pin") else "None" # comments text
      content_dict['comment'] = content.find("div", class_="_2pin").get_text() if content.find("div", class_="_2pin") else "None" # comments text
      content_dict['timestamp'] = content.find("div", class_="_3-94").get_text() # comments timestamp

      comments_list.append(content_dict)
      # print(content.get_text)

  for i in comments_list:
      print(i,'\n')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  ## Test code for json dump. Doesnt show right output
  # fp = open("foo.txt", "w")
  # fp.write(json.dumps(comments_list) + "\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# {'user': '102', 'comment': 'Aabrar ', 'timestamp': '29 Mar 2020, 17:42'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '29 Mar 2020, 09:51'}
#
# {'user': '102', 'comment': 'Bushra Esyat Jerin Ayshi jakia e post hisabe nah TMR cmnt e hisabe ask korechi 😪 jaki re upore same cmnt korsi😪', 'timestamp': '26 Mar 2020, 15:57'}
#
# {'user': '102', 'comment': 'Bushra Esyat Jerin Ayshi  Kew jante chayse?😪', 'timestamp': '26 Mar 2020, 15:34'}
#
# {'user': '102', 'comment': 'keda eta?', 'timestamp': '26 Mar 2020, 12:56'}
#
# {'user': '102', 'comment': 'kew jante chayse? :v', 'timestamp': '26 Mar 2020, 11:44'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '25 Mar 2020, 16:22'}
#
# {'user': '102', 'comment': 'Sayma Khan Eva  ki lagaydlm Tre 🤭', 'timestamp': '23 Mar 2020, 21:34'}
#
# {'user': '102', 'comment': 'Tre Kew bolse j ETA giyan de :v', 'timestamp': '23 Mar 2020, 08:54'}
#
# {'user': '102', 'comment': '❤️', 'timestamp': '23 Mar 2020, 08:52'}
#
# {'user': '102', 'comment': 'Ekne ekta chair faka ...Single ei thakbi sarajibon 🤣', 'timestamp': '23 Mar 2020, 08:48'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 Mar 2020, 14:45'}
#
# {'user': '102', 'comment': 'Istiak M. Nayem on tui bole Des :3', 'timestamp': '19 Mar 2020, 14:44'}
#
# {'user': '102', 'comment': 'Ok tatari dis dekhum :v', 'timestamp': '19 Mar 2020, 11:08'}
#
# {'user': '102', 'comment': 'Istiak M. Nayem bro ami onkdin khujsi pai nah link dbi', 'timestamp': '19 Mar 2020, 10:22'}
#
# {'user': '102', 'comment': 'Ki din aylo vut e ram ram bole :3', 'timestamp': '14 Mar 2020, 13:05'}
#
# {'user': '102', 'comment': 'ফারজানা ফাবলিহা  etar jnno ki abr rag dba nki ? 🥺', 'timestamp': '13 Mar 2020, 01:27'}
#
# {'user': '102', 'comment': 'Name same  tao banglay dekhe first vabsi nije nijek tag dso 😅', 'timestamp': '13 Mar 2020, 01:20'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '8 Mar 2020, 20:46'}
#
# {'user': '102', 'comment': 'artist keda :3', 'timestamp': '6 Mar 2020, 14:28'}
#
# {'user': '102', 'comment': 'Lol :v', 'timestamp': '5 Mar 2020, 20:36'}
#
# {'user': '102', 'comment': 'Abrar Jarif Sayma Khan Eva same time e same comment kmne :3 ', 'timestamp': '5 Mar 2020, 00:26'}
#
# {'user': '102', 'comment': 'দীপ সাহা ki j kou vai😅', 'timestamp': '5 Mar 2020, 00:25'}
#
# {'user': '102', 'comment': 'Iftekhar Ifty 2018', 'timestamp': '4 Mar 2020, 23:36'}
#
# {'user': '102', 'comment': 'Ashifa Rahman bam hat dhukas kn😒', 'timestamp': '4 Mar 2020, 23:36'}
#
# {'user': '102', 'comment': 'Tanvir Khan vaigna TMR mama k Chino na ? ', 'timestamp': '4 Mar 2020, 23:36'}
#
# {'user': '102', 'comment': 'Marjar on Fire 🔥', 'timestamp': '4 Mar 2020, 11:13'}
#
# {'user': '102', 'comment': 'Sayma Khan Eva bacchar Nam k rakhbe ETA Nye jogra lgse... Bepar na thik hoye jabe :v', 'timestamp': '1 Mar 2020, 23:00'}
#
# {'user': '102', 'comment': 'Mor loigga ek hari kacchi rakhbi... naile songsar tikbo nah :v', 'timestamp': '1 Mar 2020, 20:54'}
#
# {'user': '102', 'comment': 'Jakia Afsin ow :v', 'timestamp': '28 Feb 2020, 17:39'}
#
# {'user': '102', 'comment': 'Yeah bro :v', 'timestamp': '28 Feb 2020, 16:49'}
#
# {'user': '102', 'comment': 'Jubayer Mahmud Pranto gorgeous Tai nah?😪', 'timestamp': '23 Feb 2020, 21:39'}
#
# {'user': '102', 'comment': 'Ashifa Rahman ho', 'timestamp': '19 Feb 2020, 22:51'}
#
# {'user': '102', 'comment': 'Best 👌😍', 'timestamp': '16 Feb 2020, 10:46'}
#
# {'user': '102', 'comment': 'Ami oi dol j tiktok kori na... Abr pochai... Abr dekhio 🤣', 'timestamp': '9 Feb 2020, 22:42'}
#
# {'user': '102', 'comment': 'Wakk😒', 'timestamp': '31 Jan 2020, 10:56'}
#
# {'user': '102', 'comment': 'Isss😒', 'timestamp': '31 Jan 2020, 10:55'}
#
# {'user': '102', 'comment': '👌😍', 'timestamp': '26 Jan 2020, 18:15'}
#
# {'user': '102', 'comment': 'Uap r model 🤔', 'timestamp': '25 Jan 2020, 23:52'}
#
# {'user': '102', 'comment': 'Huh😢', 'timestamp': '24 Jan 2020, 14:02'}
#
# {'user': '102', 'comment': 'Kibtia Binte Arefin Amro janar iccha chilo 😢', 'timestamp': '24 Jan 2020, 12:54'}
#
# {'user': '102', 'comment': 'Ashifa Rahman', 'timestamp': '20 Jan 2020, 17:15'}
#
# {'user': '102', 'comment': 'biyer dawat ki pabo nah? :v', 'timestamp': '20 Jan 2020, 11:41'}
#
# {'user': '102', 'comment': 'Edi bad de ... Hsc r University Nye thak... University par howar por edi kor😒', 'timestamp': '17 Jan 2020, 20:49'}
#
# {'user': '102', 'comment': 'Shafi Ul Kamran  vorti r money receipt nki reg fee r ta just?', 'timestamp': '12 Jan 2020, 23:29'}
#
# {'user': '102', 'comment': '🤣🤣🤣🤣🤣', 'timestamp': '7 Jan 2020, 22:00'}
#
# {'user': '102', 'comment': 'Khuje Pai na to😐', 'timestamp': '7 Jan 2020, 18:51'}
#
# {'user': '102', 'comment': 'Spring ER ta Kobe dbe?', 'timestamp': '7 Jan 2020, 16:04'}
#
# {'user': '102', 'comment': 'Old town city r edik route chalu hbe na?', 'timestamp': '7 Jan 2020, 16:03'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '6 Jan 2020, 12:56'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '2 Jul 2019, 23:47'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '2 Jul 2019, 23:46'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '2 Jul 2019, 23:45'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '2 Jul 2019, 23:45'}
#
# {'user': '102', 'comment': 'Ami to boli nai j pin ready rakhte 😂😂', 'timestamp': '29 Jun 2019, 00:46'}
#
# {'user': '102', 'comment': 'Oi j bolli nah AMR nki 2 hate Tali baze nah .. so etar Prove dite chailam😂', 'timestamp': '29 Jun 2019, 00:40'}
#
# {'user': '102', 'comment': 'Ami to boli na emn kisu 😂', 'timestamp': '29 Jun 2019, 00:37'}
#
# {'user': '102', 'comment': 'TR 2 Kan niye ay dekh kmne bazai😂', 'timestamp': '29 Jun 2019, 00:35'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '29 Jun 2019, 00:34'}
#
# {'user': '102', 'comment': 'Wow nice excellent beautiful awesome xoss Tali hbe Tali 😂', 'timestamp': '29 Jun 2019, 00:34'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '29 Jun 2019, 00:33'}
#
# {'user': '102', 'comment': 'Bole laab nai Kew Tali bazabe nah 😴', 'timestamp': '29 Jun 2019, 00:31'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '29 Jun 2019, 00:30'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '29 Jun 2019, 00:28'}
#
# {'user': '102', 'comment': 'Srabonti Mondol hingse hoy😂 AMR mto hote chaw😴', 'timestamp': '29 Jun 2019, 00:27'}
#
# {'user': '102', 'comment': 'Ho😂', 'timestamp': '29 Jun 2019, 00:26'}
#
# {'user': '102', 'comment': 'Oreee 🔥 ekdm khape milse uncle auntie Jane j oi robot Tai ektu editing Kore Srabonti rakhse nahole robot ei rakhto😴', 'timestamp': '29 Jun 2019, 00:20'}
#
# {'user': '102', 'comment': 'Mohima Hossain Ayesha Kumkum so sad tmdr ei kothay Tali bazanor kono dorsok nai 😞', 'timestamp': '25 Jun 2019, 21:50'}
#
# {'user': '102', 'comment': 'Yeah TDR theke Ami better 😌', 'timestamp': '25 Jun 2019, 20:28'}
#
# {'user': '102', 'comment': '😒😒😒', 'timestamp': '22 Jun 2019, 15:43'}
#
# {'user': '102', 'comment': 'Smai😆', 'timestamp': '22 Jun 2019, 01:01'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '20 Jun 2019, 20:00'}
#
# {'user': '102', 'comment': 'Masaba Islam lol', 'timestamp': '20 Jun 2019, 00:09'}
#
# {'user': '102', 'comment': 'Oh😅', 'timestamp': '19 Jun 2019, 21:20'}
#
# {'user': '102', 'comment': 'Ashifa Rahman kn jamai vat dey nai oidin 😆', 'timestamp': '19 Jun 2019, 21:16'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 Jun 2019, 21:00'}
#
# {'user': '102', 'comment': 'Shimul Parvaz Vai portesi 😅', 'timestamp': '12 Jun 2019, 16:45'}
#
# {'user': '102', 'comment': 'Talha Jubaer lol', 'timestamp': '9 Jun 2019, 14:43'}
#
# {'user': '102', 'comment': 'Talha Jubaer ss niya rakhlm ei new season new Kore jhal mosla dite hbo nah🤣', 'timestamp': '9 Jun 2019, 14:17'}
#
# {'user': '102', 'comment': 'Kon balda chirba dekhum ne🤣🤣🤣', 'timestamp': '9 Jun 2019, 13:48'}
#
# {'user': '102', 'comment': 'Xiam on 🔥', 'timestamp': '9 Jun 2019, 01:26'}
#
# {'user': '102', 'comment': '', 'timestamp': '8 Jun 2019, 23:55'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '3 Jun 2019, 15:06'}
#
# {'user': '102', 'comment': 'ETO khn chollo Bangladesh vs South Africa now ekn suru hocche Jubayer Islam vs Masaba Islam 2 jn EI Islam nam rakhse ...darun fight hocche ... Ahsan Riyan ei niye apni ki bolben ?😆', 'timestamp': '2 Jun 2019, 23:43'}
#
# {'user': '102', 'comment': 'Tanvir Islam Ontu Sabbir Ahmed', 'timestamp': '2 Jun 2019, 22:21'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Jun 2019, 13:32'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Jun 2019, 13:20'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Jun 2019, 13:16'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Jun 2019, 13:13'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Jun 2019, 12:55'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Jun 2019, 12:53'}
#
# {'user': '102', 'comment': 'Ahsan Riyan tot ta ki begun dye tute 😆', 'timestamp': '31 May 2019, 23:02'}
#
# {'user': '102', 'comment': 'Siam Al Sadnan  😆', 'timestamp': '31 May 2019, 22:57'}
#
# {'user': '102', 'comment': 'Ahsan Riyan kn tmre dey nah time mto 🤔 ei jnno ekne chaira law😆', 'timestamp': '31 May 2019, 22:57'}
#
# {'user': '102', 'comment': 'Mane', 'timestamp': '31 May 2019, 16:24'}
#
# {'user': '102', 'comment': 'Masaba Islam....  Jubayer Islam Ekta bosti magi ei jnno Jano nah ei jnno haha dey', 'timestamp': '31 May 2019, 14:25'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '29 May 2019, 01:14'}
#
# {'user': '102', 'comment': 'TMI to kkno phn receive korba na🙂', 'timestamp': '28 May 2019, 16:38'}
#
# {'user': '102', 'comment': 'Sweetie Toma 🙂', 'timestamp': '28 May 2019, 16:37'}
#
# {'user': '102', 'comment': 'Aritro Ahmed gazipur', 'timestamp': '24 May 2019, 20:01'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '24 May 2019, 13:01'}
#
# {'user': '102', 'comment': 'Mohima Hossain 🤣🤣🤣', 'timestamp': '23 May 2019, 23:33'}
#
# {'user': '102', 'comment': 'Haha utha :3', 'timestamp': '23 May 2019, 22:05'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '23 May 2019, 21:49'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '23 May 2019, 20:58'}
#
# {'user': '102', 'comment': 'Rakibul Islam Ratul  utha', 'timestamp': '23 May 2019, 20:50'}
#
# {'user': '102', 'comment': '', 'timestamp': '23 May 2019, 19:22'}
#
# {'user': '102', 'comment': 'Rakibul Islam Ratul chulkay ?😒', 'timestamp': '23 May 2019, 15:38'}
#
# {'user': '102', 'comment': '🔥', 'timestamp': '18 May 2019, 00:51'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '17 May 2019, 23:31'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '17 May 2019, 23:28'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '17 May 2019, 23:28'}
#
# {'user': '102', 'comment': 'Ashraful Islam In sha Allah', 'timestamp': '16 May 2019, 08:11'}
#
# {'user': '102', 'comment': 'Thank you ❤️ maf kore diyen... apnader onk jalaysi 😁', 'timestamp': '15 May 2019, 20:55'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '24 Mar 2019, 15:56'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '24 Mar 2019, 10:14'}
#
# {'user': '102', 'comment': 'Ahsan Riyan lol tmi j ki chodon ta khaw Jani seta', 'timestamp': '20 Mar 2019, 19:57'}
#
# {'user': '102', 'comment': 'Ahsan Riyan TMR egula posondo hole amdr k na bole gay porn vdo dekho r techo', 'timestamp': '20 Mar 2019, 19:54'}
#
# {'user': '102', 'comment': 'Ekn Pasay fingering Kore ghumay poro', 'timestamp': '20 Mar 2019, 19:52'}
#
# {'user': '102', 'comment': 'Ahsan Riyan boss der taka deya lge nah', 'timestamp': '20 Mar 2019, 19:52'}
#
# {'user': '102', 'comment': 'Ahsan Riyan kno vabi tmk dey na tudte j AMR ta dekhe techba🙄', 'timestamp': '20 Mar 2019, 19:50'}
#
# {'user': '102', 'comment': 'Ahsan Riyan kno TMR ta ki toto', 'timestamp': '20 Mar 2019, 19:45'}
#
# {'user': '102', 'comment': 'Ahsan Riyan Kew na tudleo TMI tudo', 'timestamp': '20 Mar 2019, 19:35'}
#
# {'user': '102', 'comment': 'Tmr tota tew todeo nah 🤣', 'timestamp': '20 Mar 2019, 19:32'}
#
# {'user': '102', 'comment': 'World cup jitse Portugal jantam na😱', 'timestamp': '20 Mar 2019, 16:14'}
#
# {'user': '102', 'comment': 'Talha j eng Gali dse tre tui to  ektaro word meaning jnos nah sala abar pok pok koros🤣', 'timestamp': '13 Mar 2019, 21:06'}
#
# {'user': '102', 'comment': 'Bosti 👌', 'timestamp': '13 Mar 2019, 13:20'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '12 Mar 2019, 10:42'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '12 Mar 2019, 09:27'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '12 Mar 2019, 09:22'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '9 Mar 2019, 12:24'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '9 Mar 2019, 12:24'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '9 Mar 2019, 12:24'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '9 Mar 2019, 12:22'}
#
# {'user': '102', 'comment': 'Bal da korba 🤣', 'timestamp': '28 Feb 2019, 23:42'}
#
# {'user': '102', 'comment': 'Kuzz  muzzzz balzz ..🤣', 'timestamp': '28 Feb 2019, 22:31'}
#
# {'user': '102', 'comment': 'Rockzzzz😁', 'timestamp': '28 Feb 2019, 22:26'}
#
# {'user': '102', 'comment': 'Tui na bolisli sukoner doa manush more na 🤣 ekn proman hoilo k konda🤣', 'timestamp': '28 Feb 2019, 22:15'}
#
# {'user': '102', 'comment': 'Kew Jodi TMR dp te amr cmnt dekhe AMR jail moron uthbe😧🙄', 'timestamp': '28 Feb 2019, 15:12'}
#
# {'user': '102', 'comment': 'Vul bujhe chis valo kore dekh🐸', 'timestamp': '28 Feb 2019, 15:09'}
#
# {'user': '102', 'comment': 'Abar typing vul amr er jaygay tmi.. TMR er jaygay  Ami...ETO vul korle kmne ki🙄', 'timestamp': '28 Feb 2019, 15:07'}
#
# {'user': '102', 'comment': 'Amr likhte gye TR* likhe felsis bujhsi bolte hbe nah🙄', 'timestamp': '28 Feb 2019, 15:05'}
#
# {'user': '102', 'comment': 'Era Kara j TR dp dekhe like dilo🙄', 'timestamp': '28 Feb 2019, 14:46'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Feb 2019, 10:08'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Feb 2019, 10:07'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Feb 2019, 10:06'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Feb 2019, 10:04'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Feb 2019, 10:02'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Feb 2019, 10:00'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Feb 2019, 00:30'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Feb 2019, 00:22'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '24 Feb 2019, 12:23'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '24 Feb 2019, 11:03'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '24 Feb 2019, 11:03'}
#
# {'user': '102', 'comment': 'Ahsan Riyan lol 😂', 'timestamp': '23 Feb 2019, 10:48'}
#
# {'user': '102', 'comment': 'Thanks', 'timestamp': '23 Feb 2019, 10:21'}
#
# {'user': '102', 'comment': 'Diponkar Das lol 😂', 'timestamp': '22 Feb 2019, 22:55'}
#
# {'user': '102', 'comment': 'Boro vai ETA best👌', 'timestamp': '15 Feb 2019, 20:29'}
#
# {'user': '102', 'comment': 'Ku Mu ei jnno te sonir dosay Khushi🤣', 'timestamp': '15 Feb 2019, 12:21'}
#
# {'user': '102', 'comment': 'Ku Mu  Ami pidai nah... Ador Kori but afsos tui AMR mto TR jamai pas nai dekhe tre piday r tui protibad korar jnno fb te Des😂😂😂', 'timestamp': '14 Feb 2019, 23:50'}
#
# {'user': '102', 'comment': 'Jamai pidayse ? (2) 😂😂😂😂', 'timestamp': '14 Feb 2019, 23:40'}
#
# {'user': '102', 'comment': 'Dp hisebe perfect hoto👌', 'timestamp': '4 Feb 2019, 23:16'}
#
# {'user': '102', 'comment': 'Welcome ❤️', 'timestamp': '31 Jan 2019, 01:11'}
#
# {'user': '102', 'comment': '100 tk dya ETA sikhso dc te 🙄', 'timestamp': '27 Jan 2019, 17:47'}
#
# {'user': '102', 'comment': 'Delete koro kn doraw amare🙄', 'timestamp': '27 Jan 2019, 17:32'}
#
# {'user': '102', 'comment': 'Congratulations', 'timestamp': '26 Jan 2019, 21:04'}
#
# {'user': '102', 'comment': '❤️', 'timestamp': '24 Jan 2019, 00:16'}
#
# {'user': '102', 'comment': '❤️', 'timestamp': '24 Jan 2019, 00:16'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '23 Jan 2019, 01:08'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '23 Jan 2019, 01:07'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '23 Jan 2019, 00:47'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '23 Jan 2019, 00:47'}
#
# {'user': '102', 'comment': 'Risalate Turzo Tre dekhe gali boltese Ami ki ber hoye asbo🤓', 'timestamp': '22 Jan 2019, 22:53'}
#
# {'user': '102', 'comment': 'Musfiqul Sakib adibabibi Jani to🙄', 'timestamp': '22 Jan 2019, 22:53'}
#
# {'user': '102', 'comment': 'Abrarul Alam thomasudi 🤓', 'timestamp': '22 Jan 2019, 20:46'}
#
# {'user': '102', 'comment': 'Xsaiif Sazzad Khan  lol 😂', 'timestamp': '22 Jan 2019, 20:44'}
#
# {'user': '102', 'comment': 'Caption ND Dp 👌💯', 'timestamp': '17 Jan 2019, 16:02'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '17 Jan 2019, 00:22'}
#
# {'user': '102', 'comment': 'Hey boro vai😎', 'timestamp': '7 Jan 2019, 19:44'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '7 Jan 2019, 18:01'}
#
# {'user': '102', 'comment': 'Ahsan Riyan  oi Hala asolei asta fokkini caption dekh na ...sala', 'timestamp': '2 Jan 2019, 14:57'}
#
# {'user': '102', 'comment': 'Ganja kha tui', 'timestamp': '31 Dec 2018, 19:48'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '21 Dec 2018, 17:08'}
#
# {'user': '102', 'comment': 'Mar halare', 'timestamp': '19 Dec 2018, 22:20'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '18 Dec 2018, 01:00'}
#
# {'user': '102', 'comment': 'Mod khaye matal meyti🙄', 'timestamp': '16 Dec 2018, 13:12'}
#
# {'user': '102', 'comment': 'Oh :v', 'timestamp': '15 Dec 2018, 23:58'}
#
# {'user': '102', 'comment': 'Thanks 💙 btw 15 tarik na 16 Tarik 🙄', 'timestamp': '15 Dec 2018, 22:36'}
#
# {'user': '102', 'comment': '👌😍', 'timestamp': '15 Dec 2018, 00:26'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '14 Dec 2018, 23:35'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '14 Dec 2018, 11:27'}
#
# {'user': '102', 'comment': 'Lol 😂', 'timestamp': '14 Dec 2018, 11:24'}
#
# {'user': '102', 'comment': 'Xolli de😠', 'timestamp': '14 Dec 2018, 10:49'}
#
# {'user': '102', 'comment': 'Black love kn white nai :v', 'timestamp': '14 Dec 2018, 02:42'}
#
# {'user': '102', 'comment': 'Koi de 🤣🤣🤣', 'timestamp': '14 Dec 2018, 02:40'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '14 Dec 2018, 02:35'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '13 Dec 2018, 20:21'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:18'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:16'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:15'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': '', 'timestamp': '13 Dec 2018, 20:14'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '13 Dec 2018, 18:44'}
#
# {'user': '102', 'comment': 'Ek nayok ER student Ami...vabtei sei lgtese👌', 'timestamp': '13 Dec 2018, 18:42'}
#
# {'user': '102', 'comment': 'Ashifa Rahman 🤣🤣🤣🤣🤣🤣🤣', 'timestamp': '11 Dec 2018, 15:25'}
#
# {'user': '102', 'comment': 'Ashifa Rahman lol 😂', 'timestamp': '11 Dec 2018, 15:22'}
#
# {'user': '102', 'comment': 'Ekti haha react sarajibon ER Kanna :v', 'timestamp': '11 Dec 2018, 15:18'}
#
# {'user': '102', 'comment': 'Bell dilo na🤣', 'timestamp': '11 Dec 2018, 15:12'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '11 Dec 2018, 15:04'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '11 Dec 2018, 10:58'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '11 Dec 2018, 10:50'}
#
# {'user': '102', 'comment': 'Rounak Akter Arnaa lol 😂', 'timestamp': '10 Dec 2018, 20:17'}
#
# {'user': '102', 'comment': 'Rounak Akter Arnaa patch up hoile AMR bou pitabe😥', 'timestamp': '10 Dec 2018, 18:05'}
#
# {'user': '102', 'comment': 'AMR thakar kotha😒', 'timestamp': '10 Dec 2018, 15:02'}
#
# {'user': '102', 'comment': 'Lab nai maiya potbo new jn 🙄', 'timestamp': '7 Oct 2018, 22:54'}
#
# {'user': '102', 'comment': 'Welcome ❤️', 'timestamp': '30 Sep 2018, 16:42'}
#
# {'user': '102', 'comment': 'Lol 😂', 'timestamp': '26 Sep 2018, 01:08'}
#
# {'user': '102', 'comment': '2 tk Nye jais vat khais :v', 'timestamp': '26 Sep 2018, 01:07'}
#
# {'user': '102', 'comment': 'Koydin dhore vat khas na?...', 'timestamp': '26 Sep 2018, 01:04'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '25 Sep 2018, 21:29'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '25 Sep 2018, 16:23'}
#
# {'user': '102', 'comment': 'WOW nice excellent beautiful awesome xoss 👅', 'timestamp': '15 Sep 2018, 19:02'}
#
# {'user': '102', 'comment': "Sotti bolle dosh :')", 'timestamp': '15 Sep 2018, 18:51'}
#
# {'user': '102', 'comment': 'Ami jor nai to :3', 'timestamp': '15 Sep 2018, 18:50'}
#
# {'user': '102', 'comment': 'Luchumi korta tao :v', 'timestamp': '15 Sep 2018, 18:47'}
#
# {'user': '102', 'comment': 'Ku Mu gabay na chup chap treat dya dbi 😴', 'timestamp': '15 Sep 2018, 15:37'}
#
# {'user': '102', 'comment': 'Emotional blackmail :)', 'timestamp': '15 Sep 2018, 15:31'}
#
# {'user': '102', 'comment': 'Accha okay ..klk bolsilm pass korle treat dbi ... ready thakis xm ER por :v', 'timestamp': '15 Sep 2018, 15:27'}
#
# {'user': '102', 'comment': 'Ku Mu ei jnno 1 dsos 😂', 'timestamp': '15 Sep 2018, 15:18'}
#
# {'user': '102', 'comment': 'Ku Mu ict xm valo hoise Tai na😂😂😂😂😂😂😂😂', 'timestamp': '15 Sep 2018, 14:55'}
#
# {'user': '102', 'comment': 'Aabrar', 'timestamp': '14 Sep 2018, 23:56'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '14 Sep 2018, 00:09'}
#
# {'user': '102', 'comment': '12 ta haha react 💀', 'timestamp': '13 Sep 2018, 20:09'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '7 Sep 2018, 20:53'}
#
# {'user': '102', 'comment': "Vai du te chance pailen bollen ow na :') Kon sub e Vai? :V", 'timestamp': '1 Sep 2018, 22:01'}
#
# {'user': '102', 'comment': 'Pic ayke dile to treat dbo bolsi :3', 'timestamp': '28 Aug 2018, 00:37'}
#
# {'user': '102', 'comment': "Sobai pailo Ami pailm na :')", 'timestamp': '28 Aug 2018, 00:19'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Aug 2018, 22:14'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Aug 2018, 22:13'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Aug 2018, 20:12'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Aug 2018, 19:48'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Aug 2018, 17:03'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Aug 2018, 15:53'}
#
# {'user': '102', 'comment': 'Bday TMR tmi dba...le meridian e dile mind korbo na 😪', 'timestamp': '25 Aug 2018, 21:05'}
#
# {'user': '102', 'comment': "Tao champion hoy na ... :')", 'timestamp': '20 Aug 2018, 11:33'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Aug 2018, 20:25'}
#
# {'user': '102', 'comment': 'Baby elephant ayse porse majhe :v', 'timestamp': '1 Aug 2018, 15:53'}
#
# {'user': '102', 'comment': 'Bro Messi * :)', 'timestamp': '27 Jun 2018, 02:34'}
#
# {'user': '102', 'comment': 'Lol', 'timestamp': '26 Jun 2018, 23:42'}
#
# {'user': '102', 'comment': '😍😍😍', 'timestamp': '26 Jun 2018, 21:23'}
#
# {'user': '102', 'comment': 'Vule geli player ND captain kotha 😢', 'timestamp': '24 Jun 2018, 22:50'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '24 Jun 2018, 22:31'}
#
# {'user': '102', 'comment': '💦😴', 'timestamp': '24 Jun 2018, 22:30'}
#
# {'user': '102', 'comment': 'But TR mto captain na 💦', 'timestamp': '24 Jun 2018, 22:29'}
#
# {'user': '102', 'comment': 'Lol 😂', 'timestamp': '24 Jun 2018, 22:29'}
#
# {'user': '102', 'comment': 'Chapa kom maren😂', 'timestamp': '20 Jun 2018, 22:24'}
#
# {'user': '102', 'comment': 'Tanvir Islam Ontu💦', 'timestamp': '20 Jun 2018, 12:52'}
#
# {'user': '102', 'comment': ":')", 'timestamp': '19 Jun 2018, 23:44'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 Jun 2018, 21:55'}
#
# {'user': '102', 'comment': 'Simple ER modde gorgeous 😍', 'timestamp': '17 Jun 2018, 16:35'}
#
# {'user': '102', 'comment': 'Coz nai j tmr😴', 'timestamp': '12 Jun 2018, 01:09'}
#
# {'user': '102', 'comment': 'Jealous?😴', 'timestamp': '12 Jun 2018, 01:08'}
#
# {'user': '102', 'comment': 'Wow bap r nc pola AMR pise lgse 🐸', 'timestamp': '12 Jun 2018, 00:50'}
#
# {'user': '102', 'comment': 'TR bap re bst frnd Kos🐸', 'timestamp': '12 Jun 2018, 00:47'}
#
# {'user': '102', 'comment': '', 'timestamp': '12 Jun 2018, 00:30'}
#
# {'user': '102', 'comment': 'Upload dile kmn hoy?😋', 'timestamp': '12 Jun 2018, 00:26'}
#
# {'user': '102', 'comment': 'AMR timeline e', 'timestamp': '12 Jun 2018, 00:26'}
#
# {'user': '102', 'comment': '', 'timestamp': '12 Jun 2018, 00:26'}
#
# {'user': '102', 'comment': 'Revenge Kare koy or maye bujhbo', 'timestamp': '12 Jun 2018, 00:22'}
#
# {'user': '102', 'comment': 'Or pic upload dmu', 'timestamp': '12 Jun 2018, 00:21'}
#
# {'user': '102', 'comment': 'Dekg ekn', 'timestamp': '12 Jun 2018, 00:21'}
#
# {'user': '102', 'comment': 'Ku Mu 😏', 'timestamp': '6 Jun 2018, 18:05'}
#
# {'user': '102', 'comment': 'Golu golu 😍', 'timestamp': '6 Jun 2018, 18:01'}
#
# {'user': '102', 'comment': "ETA 10 bar dekhsi...vlo lgse ...pore location dekhlm mejaj gorom hoye gese :')", 'timestamp': '4 Jun 2018, 23:54'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '2 Jun 2018, 17:59'}
#
# {'user': '102', 'comment': '4G korsi but offer paini :)', 'timestamp': '1 Jun 2018, 12:22'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '1 Jun 2018, 12:15'}
#
# {'user': '102', 'comment': 'Congratulations 😴', 'timestamp': '29 May 2018, 16:18'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 May 2018, 18:09'}
#
# {'user': '102', 'comment': '❤️', 'timestamp': '25 May 2018, 22:25'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '25 May 2018, 21:39'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '25 May 2018, 21:39'}
#
# {'user': '102', 'comment': 'Ahsan Riyan', 'timestamp': '23 May 2018, 23:17'}
#
# {'user': '102', 'comment': 'Cute onk😍', 'timestamp': '23 May 2018, 21:52'}
#
# {'user': '102', 'comment': '😍💞', 'timestamp': '23 May 2018, 21:51'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 23:37'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 23:34'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 23:32'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 23:32'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 23:31'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 21:06'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 20:49'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 19:05'}
#
# {'user': '102', 'comment': '🙃🙃🙃', 'timestamp': '19 May 2018, 15:30'}
#
# {'user': '102', 'comment': '🙃🙃🙃🙃🙃', 'timestamp': '19 May 2018, 15:18'}
#
# {'user': '102', 'comment': 'Mohima Hossain 🙃', 'timestamp': '19 May 2018, 15:15'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 15:15'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 15:15'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 15:13'}
#
# {'user': '102', 'comment': 'Mohima Hossain Tre Jodi emne pidayte partam 🙃', 'timestamp': '19 May 2018, 15:12'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 15:08'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 15:07'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 15:01'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '19 May 2018, 13:45'}
#
# {'user': '102', 'comment': '💝', 'timestamp': '15 May 2018, 21:02'}
#
# {'user': '102', 'comment': 'ki j bolen vai 😂', 'timestamp': '15 May 2018, 00:02'}
#
# {'user': '102', 'comment': 'Wlcm💝', 'timestamp': '13 May 2018, 17:12'}
#
# {'user': '102', 'comment': 'Hae Jani tr ta😂', 'timestamp': '12 May 2018, 00:35'}
#
# {'user': '102', 'comment': 'Tre?🤔', 'timestamp': '12 May 2018, 00:34'}
#
# {'user': '102', 'comment': 'Crush', 'timestamp': '12 May 2018, 00:32'}
#
# {'user': '102', 'comment': 'Excellent', 'timestamp': '12 May 2018, 00:31'}
#
# {'user': '102', 'comment': 'Beautiful', 'timestamp': '12 May 2018, 00:31'}
#
# {'user': '102', 'comment': 'Nice', 'timestamp': '12 May 2018, 00:31'}
#
# {'user': '102', 'comment': 'Wow', 'timestamp': '12 May 2018, 00:31'}
#
# {'user': '102', 'comment': 'Aha 😍👌 🔥', 'timestamp': '12 May 2018, 00:30'}
#
# {'user': '102', 'comment': 'Ultay nai taile to bujhli valo kotha boli nai😂😂😂', 'timestamp': '12 May 2018, 00:28'}
#
# {'user': '102', 'comment': 'Bllm TR ei dp Facebook profile picture crash khaise ... abal 😒 vala koileo dosh😒', 'timestamp': '12 May 2018, 00:25'}
#
# {'user': '102', 'comment': 'Jantam Ulta bujhbi😏', 'timestamp': '12 May 2018, 00:22'}
#
# {'user': '102', 'comment': 'Sorry Crash hbe TR jnno Facebook profile picture crash khaise🙄', 'timestamp': '12 May 2018, 00:19'}
#
# {'user': '102', 'comment': 'Crush 😯', 'timestamp': '12 May 2018, 00:11'}
#
# {'user': '102', 'comment': 'Roadies*', 'timestamp': '10 May 2018, 19:18'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '9 May 2018, 01:59'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '6 May 2018, 02:08'}
#
# {'user': '102', 'comment': 'Tuu Rab', 'timestamp': '5 May 2018, 02:13'}
#
# {'user': '102', 'comment': 'Tuu Rab', 'timestamp': '5 May 2018, 01:59'}
#
# {'user': '102', 'comment': 'Accha dei', 'timestamp': '5 May 2018, 01:52'}
#
# {'user': '102', 'comment': 'Mohima r zinia re koya dekhi Ora ki bole tui nki Ami?🤔', 'timestamp': '5 May 2018, 01:49'}
#
# {'user': '102', 'comment': 'Mentioned korum?', 'timestamp': '5 May 2018, 00:42'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '4 May 2018, 20:58'}
#
# {'user': '102', 'comment': '👌😍', 'timestamp': '3 May 2018, 13:12'}
#
# {'user': '102', 'comment': 'Gola 🔥', 'timestamp': '2 May 2018, 19:53'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '2 May 2018, 19:34'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '2 May 2018, 16:45'}
#
# {'user': '102', 'comment': 'Nazmul Haque Risalate Turzo', 'timestamp': '30 Apr 2018, 22:42'}
#
# {'user': '102', 'comment': 'kbe?', 'timestamp': '28 Apr 2018, 22:44'}
#
# {'user': '102', 'comment': 'yea', 'timestamp': '28 Apr 2018, 22:44'}
#
# {'user': '102', 'comment': 'yellow cafe!', 'timestamp': '28 Apr 2018, 00:18'}
#
# {'user': '102', 'comment': 'Bujhbi na🤣', 'timestamp': '28 Apr 2018, 00:17'}
#
# {'user': '102', 'comment': 'Tuu Rab', 'timestamp': '27 Apr 2018, 15:00'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Apr 2018, 19:51'}
#
# {'user': '102', 'comment': 'Tre sei manayse😪', 'timestamp': '24 Apr 2018, 22:51'}
#
# {'user': '102', 'comment': 'Khabar er pic dekhsos?', 'timestamp': '24 Apr 2018, 16:46'}
#
# {'user': '102', 'comment': 'Ahsan Riyan', 'timestamp': '23 Apr 2018, 23:50'}
#
# {'user': '102', 'comment': 'Hae', 'timestamp': '22 Apr 2018, 23:31'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '22 Apr 2018, 15:16'}
#
# {'user': '102', 'comment': 'Hae😋', 'timestamp': '21 Apr 2018, 23:09'}
#
# {'user': '102', 'comment': 'Lol', 'timestamp': '21 Apr 2018, 23:09'}
#
# {'user': '102', 'comment': 'Nusrat JHa😂😂', 'timestamp': '21 Apr 2018, 22:50'}
#
# {'user': '102', 'comment': 'Mohima Hossain🤣🤣', 'timestamp': '21 Apr 2018, 22:50'}
#
# {'user': '102', 'comment': 'Ku Mu👌🤣', 'timestamp': '21 Apr 2018, 22:50'}
#
# {'user': '102', 'comment': 'Ho etar kothai koite vule gesilm basay', 'timestamp': '20 Apr 2018, 23:59'}
#
# {'user': '102', 'comment': 'Accha Dekhi', 'timestamp': '20 Apr 2018, 23:08'}
#
# {'user': '102', 'comment': 'Pore loss khaile tk k dbo😒', 'timestamp': '20 Apr 2018, 23:04'}
#
# {'user': '102', 'comment': 'Odr loss khaway laab ase🤣🤣', 'timestamp': '20 Apr 2018, 22:57'}
#
# {'user': '102', 'comment': 'Referee apnak ow dbe tension niyen na ;)', 'timestamp': '20 Apr 2018, 21:23'}
#
# {'user': '102', 'comment': 'Page e Barca k pochano hoy! Sob team er kotha ase ager Vdo dekho ETA excuse na bro :5 Sotti kotha bolle to dosh :6', 'timestamp': '20 Apr 2018, 21:18'}
#
# {'user': '102', 'comment': 'Tanvir Islam Ontu', 'timestamp': '20 Apr 2018, 21:14'}
#
# {'user': '102', 'comment': 'Vag🤣', 'timestamp': '16 Apr 2018, 23:38'}
#
# {'user': '102', 'comment': 'Mohima Hossain ETA na uthayleo cholbe :v', 'timestamp': '16 Apr 2018, 23:32'}
#
# {'user': '102', 'comment': 'Ekni', 'timestamp': '16 Apr 2018, 23:29'}
#
# {'user': '102', 'comment': 'Tui utha age tarpor uthamu suru korsis ses tui kor Ami promise dilm uthabo', 'timestamp': '16 Apr 2018, 23:29'}
#
# {'user': '102', 'comment': 'Accha sorry uthan apni :)', 'timestamp': '16 Apr 2018, 23:27'}
#
# {'user': '102', 'comment': 'Utha😒', 'timestamp': '16 Apr 2018, 23:26'}
#
# {'user': '102', 'comment': 'Mohima Hossain haha uthabi nki Tre duniya theke uthay dmu 😒😒😒 R.I.P hoye jabi koilm', 'timestamp': '16 Apr 2018, 23:21'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '16 Apr 2018, 20:54'}
#
# {'user': '102', 'comment': 'Lol😒', 'timestamp': '15 Apr 2018, 23:33'}
#
# {'user': '102', 'comment': '❤️', 'timestamp': '15 Apr 2018, 23:32'}
#
# {'user': '102', 'comment': 'Samne 16 tarik er por?', 'timestamp': '11 Apr 2018, 22:37'}
#
# {'user': '102', 'comment': 'Sei to😍', 'timestamp': '11 Apr 2018, 22:37'}
#
# {'user': '102', 'comment': 'Lol🤣🤣', 'timestamp': '10 Apr 2018, 23:55'}
#
# {'user': '102', 'comment': '😂😂😂😂', 'timestamp': '10 Apr 2018, 19:57'}
#
# {'user': '102', 'comment': '', 'timestamp': '10 Apr 2018, 19:55'}
#
# {'user': '102', 'comment': 'Penakota*', 'timestamp': '10 Apr 2018, 19:54'}
#
# {'user': '102', 'comment': 'Mal 🔥', 'timestamp': '8 Apr 2018, 00:34'}
#
# {'user': '102', 'comment': 'Alys to Tai boli🙄😏', 'timestamp': '7 Apr 2018, 22:56'}
#
# {'user': '102', 'comment': 'Ami kharap kbe koisi?😑😒', 'timestamp': '7 Apr 2018, 22:42'}
#
# {'user': '102', 'comment': 'Aye roshogolla😍😋', 'timestamp': '7 Apr 2018, 21:02'}
#
# {'user': '102', 'comment': 'Offer kotodin ase?', 'timestamp': '6 Apr 2018, 18:12'}
#
# {'user': '102', 'comment': 'Sabbir Ahmed', 'timestamp': '3 Apr 2018, 15:11'}
#
# {'user': '102', 'comment': ':)', 'timestamp': '3 Apr 2018, 00:19'}
#
# {'user': '102', 'comment': '😍❤️', 'timestamp': '2 Apr 2018, 00:08'}
#
# {'user': '102', 'comment': 'Lol', 'timestamp': '31 Mar 2018, 23:06'}
#
# {'user': '102', 'comment': "Sazzad thakle abrar kisu hoilo :')", 'timestamp': '31 Mar 2018, 21:10'}
#
# {'user': '102', 'comment': 'Ekn to TMI jatir crush ..tmdr ei din Vai :)', 'timestamp': '31 Mar 2018, 21:04'}
#
# {'user': '102', 'comment': 'AMR vat kaira nilo :)', 'timestamp': '31 Mar 2018, 21:03'}
#
# {'user': '102', 'comment': 'Sob koytai😍', 'timestamp': '30 Mar 2018, 13:56'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '28 Mar 2018, 21:21'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '28 Mar 2018, 21:04'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Mar 2018, 07:36'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '27 Mar 2018, 00:46'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:51'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:47'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:46'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:46'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:44'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:40'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:40'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:38'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 22:36'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 21:09'}
#
# {'user': '102', 'comment': 'None', 'timestamp': '26 Mar 2018, 21:08'}
#
# ...
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 3, 2020, 4:48 PM'}
#
# {'user': '89', 'comment': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 3, 2020, 3:59 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:32 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:30 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:30 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:29 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:27 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:12 PM'}
#
# {'user': '89', 'comment': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'comment': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'comment': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench\n#BoycottFrenchProducts\n#WeLoveMuhammad(SAW)\n#WeFollowMuhammad(SAW)\n#LaIlahaIllallahuMuhammadurRasulullah\n#ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'comment': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 5:58 PM'}
#
# {'user': '89', 'comment': 'Shabiha Borsha huhh, jaa sor :\\', 'timestamp': 'Oct 30, 2020, 11:22 PM'}
#
# {'user': '89', 'comment': 'Shabiha Borsha okk😏😏', 'timestamp': 'Oct 30, 2020, 11:18 PM'}
#
# {'user': '89', 'comment': 'Shabiha Borsha naaa, dawat o to dila na🙂 dawat dile nyle ekta rost beshiy khaitam..tai boila dawat dila na🙂', 'timestamp': 'Oct 30, 2020, 11:12 PM'}
#
# {'user': '89', 'comment': 'Biya koira felaiso naki?', 'timestamp': 'Oct 30, 2020, 11:10 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫\n#BoycottFrance❎\n#WeLoveMohammadﷺ❤️\n#WeFollowMohammadﷺ❤️\n#WeAreUmmahOfMohammadﷺ❤️\n#WeHateFrancegovernment\n#boycotfrance❌\n#ফ্রান্সপন্যবর্জনকরুন✖️\n#LoveProphetMuhammadﷺ❤\n#MyProphetMyHonour❤️\n#Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:52 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫\n#BoycottFrance❎\n#WeLoveMohammadﷺ❤️\n#WeFollowMohammadﷺ❤️\n#WeAreUmmahOfMohammadﷺ❤️\n#WeHateFrancegovernment\n#boycotfrance❌\n#ফ্রান্সপন্যবর্জনকরুন✖️\n#LoveProphetMuhammadﷺ❤\n#MyProphetMyHonour❤️\n#Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:52 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫\n#BoycottFrance❎\n#WeLoveMohammadﷺ❤️\n#WeFollowMohammadﷺ❤️\n#WeAreUmmahOfMohammadﷺ❤️\n#WeHateFrancegovernment\n#boycotfrance❌\n#ফ্রান্সপন্যবর্জনকরুন✖️\n#LoveProphetMuhammadﷺ❤\n#MyProphetMyHonour❤️\n#Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:52 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫\n#BoycottFrance❎\n#WeLoveMohammadﷺ❤️\n#WeFollowMohammadﷺ❤️\n#WeAreUmmahOfMohammadﷺ❤️\n#WeHateFrancegovernment\n#boycotfrance❌\n#ফ্রান্সপন্যবর্জনকরুন✖️\n#LoveProphetMuhammadﷺ❤\n#MyProphetMyHonour❤️\n#Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫\n#BoycottFrance❎\n#WeLoveMohammadﷺ❤️\n#WeFollowMohammadﷺ❤️\n#WeAreUmmahOfMohammadﷺ❤️\n#WeHateFrancegovernment\n#boycotfrance❌\n#ফ্রান্সপন্যবর্জনকরুন✖️\n#LoveProphetMuhammadﷺ❤\n#MyProphetMyHonour❤️\n#Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫 #BoycottFrance❎ #WeLoveMohammadﷺ❤️ #WeFollowMohammadﷺ❤️ #WeAreUmmahOfMohammadﷺ❤️ #WeHateFrancegovernment #boycotfrance❌ #ফ্রান্সপন্যবর্জনকরুন✖️ #LoveProphetMuhammadﷺ❤ #MyProphetMyHonour❤️ #Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:49 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫\n#BoycottFrance❎\n#WeLoveMohammadﷺ❤️\n#WeFollowMohammadﷺ❤️\n#WeAreUmmahOfMohammadﷺ❤️\n#WeHateFrancegovernment\n#boycotfrance❌\n#ফ্রান্সপন্যবর্জনকরুন✖️\n#LoveProphetMuhammadﷺ❤\n#MyProphetMyHonour❤️\n#Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:48 PM'}
#
# {'user': '89', 'comment': 'None', 'timestamp': 'Oct 30, 2020, 2:48 PM'}
#
# {'user': '89', 'comment': '#BoycottFranceProducts🚫\n#BoycottFrance❎\n#WeLoveMohammadﷺ❤️\n#WeFollowMohammadﷺ❤️\n#WeAreUmmahOfMohammadﷺ❤️\n#WeHateFrancegovernment\n#boycotfrance❌\n#ফ্রান্সপন্যবর্জনকরুন✖️\n#LoveProphetMuhammadﷺ❤\n#MyProphetMyHonour❤️\n#Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:48 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 29, 2020, 12:54 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 11:37 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:49 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:41 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:41 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:38 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:31 AM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:31 AM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:29 AM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:55 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:50 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:49 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:48 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:34 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products', 'timestamp': 'Oct 26, 2020, 10:43 PM'}
#
# {'user': '89', 'comment': '#Boycott_French_Products ', 'timestamp': 'Oct 26, 2020, 10:38 PM'}
#
# {'user': '89', 'comment': 'Fake news vai', 'timestamp': 'Oct 26, 2020, 6:39 PM'}
#
# {'user': '89', 'comment': '#Boycot_french_Products ', 'timestamp': 'Oct 26, 2020, 6:12 PM'}
#
# {'user': '89', 'comment': 'Congress!', 'timestamp': 'Sep 27, 2020, 9:08 PM'}
#
# {'user': '89', 'comment': 'https://media1.tenor.co/images/c2c1c712ac3e9f8726106c8b8bad0cbf/tenor.gif?itemid=17112377', 'timestamp': 'Sep 25, 2020, 3:47 PM'}
#
# {'user': '89', 'comment': 'Md Wasik Jewel naa amre dekh🙂', 'timestamp': 'Sep 25, 2020, 3:42 PM'}
#
# {'user': '89', 'comment': 'https://media3.giphy.com/media/v1.Y2lkPTEyMGMwMTQ3ZmNhNzc4NjNhMjUxZTY2NTMyODNiMDUwMzFlMzFkMDdjNThmNGY2OQ/eJT738HFSQDVS/giphy.gif', 'timestamp': 'Sep 25, 2020, 12:01 AM'}
#
# {'user': '89', 'comment': 'Syed ALi AhSan ailo milla gese🙄', 'timestamp': 'Sep 24, 2020, 11:58 PM'}
#
# {'user': '89', 'comment': 'Sei lgtachee!!', 'timestamp': 'Sep 24, 2020, 3:46 PM'}
#
# {'user': '89', 'comment': 'Ay hay ami to jainna laisi tr weakness!! Ki hobe ekhn!!🙂', 'timestamp': 'Sep 24, 2020, 3:22 PM'}
#
# {'user': '89', 'comment': 'Pi Al kon jaygay aida??🙄', 'timestamp': 'Sep 21, 2020, 6:06 PM'}
#
# {'user': '89', 'comment': 'Congratulations bondhu❤', 'timestamp': 'Sep 20, 2020, 4:04 PM'}
#
# {'user': '89', 'comment': 'Sh Efty sukkur bar e ami ahi mama Tui ahis dekha hoibo', 'timestamp': 'Sep 16, 2020, 10:26 PM'}
#
# {'user': '89', 'comment': 'Sh Efty ahhaa😍😍 Okk bndhu sighroi deha hoibo', 'timestamp': 'Sep 16, 2020, 10:21 PM'}
#
# {'user': '89', 'comment': 'Sh Efty ki korsi ami🙄', 'timestamp': 'Sep 16, 2020, 10:16 PM'}
#
# {'user': '89', 'comment': 'Mohammad Shahariar  yes bondhu Ki khbr??', 'timestamp': 'Sep 16, 2020, 9:50 PM'}
#
# {'user': '89', 'comment': 'Sultan Nurnobi হ ভাই, কিছুটা😅', 'timestamp': 'Sep 16, 2020, 9:47 PM'}
#
# {'user': '89', 'comment': 'Hahahahhaha...আলহামদুলিল্লাহ ,কুরআন আমার জন্য আল্লাহর রহমতে হেদায়েত।  আর ভাই আপনার কি মনে হয়, আপনি পবিত্র কুরআন ঘট ঘট করে পরবেন আর ঘট ঘট করে সব বুজে ফেলবেন? এতই সোজা?  হাহাহাহা।।। উদাহরণ দেয়, ধরুন আপনি ক্লাস ৮-ই উঠলেন ফ্রাস্ট টাইম নিউটনের ১ম সুত্র পড়লেন আর বুজে যাবেন? নিশ্চয়ই বুজবেন না, তাহলে আপনি সর্বশক্তিমান, মহান আল্লাহ যিনি আপনাকে, আমাকে, নিউটনকে, পৃথিবীর সব মাখলুক কে যিনি জ্ঞান দান করছেন না জানি তার কাছে কত জ্ঞান!! সেই আল্লাহর বানী আপনি এত সহজেই বুজে যাবেন?? আপনি ধৈয্য ধারণ করে সত্য জানা ও বুঝার চেষ্টা করুন। ইনশাআল্লাহ আপনি সত্য বুঝতে পারবেন, ইনশাআল্লাহ আপনি হেদায়েত পাবেন।। ধন্যবাদ। ', 'timestamp': 'Sep 14, 2020, 10:55 AM'}
#
# {'user': '89', 'comment': 'আপনাদের উদেশ্য সরল মুসলিমদের মনে বিভ্রান্তি সৃষ্টি করা ও তুচ্ছ মিথ্যা বিষয়বস্তু ছড়ানো।  তাদের কথার কোনো মুসলিম ভাই-বোন বিভ্রান্তি তে যাবেন না।', 'timestamp': 'Sep 14, 2020, 9:41 AM'}
#
# {'user': '89', 'comment': 'এইভাবে অপপ্রচার বন্ধ করুন। ', 'timestamp': 'Sep 4, 2020, 3:12 PM'}
#
# {'user': '89', 'comment': '❤❤❤❤', 'timestamp': 'Aug 29, 2020, 10:53 PM'}
#
# {'user': '89', 'comment': 'বাটপারি ছাড়ো মিয়া', 'timestamp': 'Aug 28, 2020, 6:24 PM'}
#
# {'user': '89', 'comment': ' (খ) অনি A.I. Mehedi Hasan Zahirul Islam Angel Suvra', 'timestamp': 'Aug 23, 2020, 11:44 AM'}
#
# {'user': '89', 'comment': 'আবু হেনা মোস্তফা কামাল।', 'timestamp': 'Aug 23, 2020, 11:41 AM'}
#
# {'user': '89', 'comment': '❤❤❤', 'timestamp': 'Aug 16, 2020, 8:40 PM'}
#
# {'user': '89', 'comment': 'Pi Al mne ki aidar😑 ami to ahono aitai bujhlam naaaa😑', 'timestamp': 'Aug 11, 2020, 7:09 PM'}
#
# {'user': '89', 'comment': 'Price???', 'timestamp': 'Aug 11, 2020, 12:13 AM'}
#
# {'user': '89', 'comment': 'Okk sir😍', 'timestamp': 'Aug 10, 2020, 10:53 PM'}
#
# {'user': '89', 'comment': 'Osthiiirr😍😍😍', 'timestamp': 'Aug 5, 2020, 10:02 PM'}
#
# {'user': '89', 'comment': 'Masha-Allah Subhan-Allah❤❤', 'timestamp': 'Jul 29, 2020, 12:16 PM'}
#
# {'user': '89', 'comment': 'আমিন।❤❤❤', 'timestamp': 'Jul 29, 2020, 10:35 AM'}
#
# {'user': '89', 'comment': 'আল্লাহ আপনার জ্ঞান আরো বাড়িয়ে দিক ভাই। ❤❤', 'timestamp': 'Jul 24, 2020, 6:31 PM'}
#
# {'user': '89', 'comment': 'Fahim Morshed Miajee haee vai, setai uchit chilo', 'timestamp': 'Jul 9, 2020, 8:08 PM'}
#
# {'user': '89', 'comment': 'The person who share this post\nযদি ওই মেয়ের জায়গায় আপনার নিজের বোন থাকতো তাইলে কি আপনি ঠিক এমন ভাবেই এই পোস্ট শেয়ার দিতেন?\nযদি উওর হয় না! তাইলে পরের বোনের এমন টাইপের ভিডিও শেয়ার দিলেন কেন???', 'timestamp': 'Jul 9, 2020, 3:46 PM'}
#
# {'user': '89', 'comment': "Fuck this kind of shit scene .. Us has high quality media so they promote in the media they are innocent, and Muslim are terrorist.  But in reality they are terrorist.  They killed thousand of Palestine's people but no! Muslim are terrorist!!!  They killed thousand of iraq's people but no! Muslim are terrorist!!!  They killed thousand of Afghanistan's people but no! Muslim are terrorist!!!  Shame!! Shamee!!", 'timestamp': 'Jul 5, 2020, 5:01 PM'}
#
# {'user': '89', 'comment': 'Asoleeiii amr emn lge mjhe mjhe😑😪', 'timestamp': 'Jul 5, 2020, 2:48 PM'}
#
# {'user': '89', 'comment': 'Seeii seiii😍😍', 'timestamp': 'Jun 27, 2020, 10:22 AM'}
#
# {'user': '89', 'comment': '40% discount ache akhono?', 'timestamp': 'Jun 18, 2020, 9:02 PM'}
#
# {'user': '89', 'comment': 'Pi Al thenkuu', 'timestamp': 'Jun 12, 2020, 9:28 AM'}
#
# {'user': '89', 'comment': 'Sundor hoy nai!!☹☹', 'timestamp': 'Jun 11, 2020, 6:01 PM'}
#
# {'user': '89', 'comment': 'তাহমিনা জান্নাত hooo😪😪 Ahhh re koto din omne party kori na!!!🙂', 'timestamp': 'Jun 4, 2020, 3:58 PM'}
#
# {'user': '89', 'comment': 'Md Obaidullah thk thk koya lgbo naaa', 'timestamp': 'Jun 4, 2020, 10:08 AM'}
#
# {'user': '89', 'comment': 'Johon Oscar bair hoisilo tohon Oscar O khaitam emne😂', 'timestamp': 'Jun 4, 2020, 9:48 AM'}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# Post Scraper

# %%
# Opening the html file. If the file
# is present in different location, 
# exact location need to be mentioned

for user in users_list: # goes through each user in the folder
  post_filedir = f"/content/users/{user}/posts/your_posts_1.html"
  HTMLFileToBeOpened = codecs.open(post_filedir, "r", "utf-8") # use codecs.open to open html files!
    
  # Reading the file and storing in a variable
  contents = HTMLFileToBeOpened.read()
    
  # Creating a BeautifulSoup object and
  # specifying the parser 
  soup = BeautifulSoup(contents, 'lxml')


  posts_list = []

  for content in soup.find_all("div", class_="pam"): # content div of each comment
      # print(content,'\n')

      content_dict = {} # create a dictionary for each comment section
      content_dict['user'] = user # create 41 as user id
      content_dict['post'] = content.find("div", class_="_3-95").get_text() if content.find("div", class_="_3-95") else "None" # post text
      content_dict['post'] = content_dict['post'].replace('\n', ' ') # removes \n from post 
      content_dict['timestamp'] = content.find("div", class_="_3-94").get_text() # comments timestamp

      posts_list.append(content_dict)

  for i in posts_list:
      print(i,'\n')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# {'user': '41', 'post': 'গাড়িতে জিপিএস ট্র্যাকার লাগানোর জন্য একজন অভিজ্ঞ লোক দরকার, উনার কাজ হবে ঢাকা শহরের বিভিন্ন জায়গায় আমাদের কাস্টমারদের গাড়িতে জিপিএস ট্র্যাকার লাগিয়ে দিয়ে আসতে হবে।  যোগাযোগ: 01558971505', 'timestamp': 'Jan 8, 2021, 5:50 PM'}
#
# {'user': '41', 'post': 'গাড়িতে জিপিএস ট্র্যাকার লাগানোর জন্য একজন অভিজ্ঞ লোক দরকার, উনার কাজ হবে ঢাকা শহরের বিভিন্ন জায়গায় আমাদের কাস্টমারদের গাড়িতে জিপিএস ট্র্যাকার লাগিয়ে দিয়ে আসতে হবে ।  অফিস লোকেশন: মিরপুর ডিওএইচএস, ঢাকা। যোগাযোগ: 01558971505', 'timestamp': 'Jan 8, 2021, 2:35 PM'}
#
# {'user': '41', 'post': 'গাড়িতে জিপিএস ট্র্যাকার লাগানোর জন্য একজন অভিজ্ঞ লোক দরকার, উনার কাজ হবে ঢাকা শহরের বিভিন্ন জায়গায় আমাদের কাস্টমারদের গাড়িতে জিপিএস ট্র্যাকার লাগিয়ে দিয়ে আসতে হবে ।  অফিস লোকেশন: মিরপুর ডিওএইচএস, ঢাকা। যোগাযোগ: 01558971505', 'timestamp': 'Jan 8, 2021, 2:27 PM'}
#
# {'user': '41', 'post': 'গাড়িতে জিপিএস ট্র্যাকার লাগানোর জন্য একজন অভিজ্ঞ লোক দরকার, উনার কাজ হবে ঢাকা শহরের বিভিন্ন জায়গায় আমাদের কাস্টমারদের গাড়িতে জিপিএস ট্র্যাকার লাগিয়ে দিয়ে আসতে হবে ।  অফিস লোকেশন: মিরপুর ডিওএইচএস, ঢাকা। যোগাযোগ: 01558971505', 'timestamp': 'Jan 8, 2021, 2:27 PM'}
#
# {'user': '41', 'post': '', 'timestamp': 'Jan 3, 2021, 1:18 PM'}
#
# {'user': '41', 'post': 'শুভ জন্মদিন সাকিব, জীবনে অনেক বড় হও এই দোয়া রইল।', 'timestamp': 'Dec 24, 2020, 10:35 AM'}
#
# {'user': '41', 'post': 'Good morning 🌞', 'timestamp': 'Dec 12, 2020, 8:49 AM'}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {
PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Oct 5, 2020, 3:39 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Oct 3, 2020, 10:09 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Sep 28, 2020, 6:07 PM'}
#
# {'user': '57', 'post': 'Happy birthday vai! 🎂❤', 'timestamp': 'Sep 10, 2020, 3:54 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Sep 7, 2020, 10:51 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Sep 6, 2020, 10:33 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Sep 3, 2020, 10:10 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Aug 24, 2020, 1:47 PM'}
#
# {'user': '57', 'post': 'শুভ জন্মদিন মুরুব্বি!🎂❤ ট্রিট দিয়েন, তাইলে বড় কইরা wish করমু!🙄😑', 'timestamp': 'Aug 24, 2020, 12:07 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Aug 24, 2020, 3:31 AM'}
#
# {'user': '57', 'post': 'This is football!❤', 'timestamp': 'Aug 15, 2020, 1:37 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Aug 12, 2020, 11:05 PM'}
#
# {'user': '57', 'post': 'Happy birthday @[100010937193624:2048:Jakia]!!🎂 Treat bkash koris!😑🙄', 'timestamp': 'Aug 1, 2020, 2:12 PM'}
#
# {'user': '57', 'post': 'Happy birthday vaia... 🥳❤🎂', 'timestamp': 'Jul 16, 2020, 12:08 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Jul 1, 2020, 7:35 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Jun 29, 2020, 11:27 AM'}
#
# {'user': '57', 'post': '🙄', 'timestamp': 'Jun 27, 2020, 9:35 PM'}
#
# {'user': '57', 'post': 'Location : Muladi Device : সামসু এন জি A50', 'timestamp': 'Jun 20, 2020, 9:36 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Jun 15, 2020, 12:10 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Jun 14, 2020, 3:30 PM'}
#
# {'user': '57', 'post': 'See full photo', 'timestamp': 'Jun 10, 2020, 8:50 PM'}
#
# {'user': '57', 'post': 'Happy birthday vau!🎂❤', 'timestamp': 'Jun 4, 2020, 10:36 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'May 30, 2020, 12:26 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'May 24, 2020, 2:57 AM'}
#
# {'user': '57', 'post': 'kabir singh lite😑', 'timestamp': 'May 23, 2020, 11:31 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'May 16, 2020, 10:05 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'May 15, 2020, 7:02 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'May 12, 2020, 10:45 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'May 4, 2020, 4:04 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'May 2, 2020, 5:54 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Apr 13, 2020, 12:33 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Apr 13, 2020, 12:30 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Apr 11, 2020, 2:10 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Apr 9, 2020, 12:31 PM'}
#
# {'user': '57', 'post': 'None', 'timestamp': 'Mar 29, 2020, 10:52 PM'}
#
# {'user': '57', 'post': 'চ্যালেঞ্জ এক্সেপ্ট তো অনেক হল। আসুন না এবার এগিয়ে আসি আসল চ্যালেঞ্জ মোকাবিলায়। আপনার দেয়া কিছু অনুদান সেচ্ছাসেবীদের হাত ধরে পৌছে যাক দুস্থ মানুষের দ্বারে। আমাদের ১০ জন এর টাকাও যদি একটি পরিবারের জন্য এই মহামারীতে আশীর্বাদ হয়ে আসে!!!   আসুন না ট্রেন্ড খুলে ফেলি। টাকা ডোনেট করার পর নিজেরাই নিজেদের শেয়ার দেয়া পোস্ট এ অন্তত ৪ জনকে মেনশন করা শুরু করি। যারা অন্তত ১০ টি করে টাকা ডোনেট করার পর নিজেরা পোস্ট শেয়ার করে আরো 10 জনকে মেনশন করে দিবে।  Challenge accepted from : Tanvir Khan  Share your screenshots to inspire others and tell them to share theirs.  https://www.bkash.com/donation   #DonateBidyanondo #Bidyanondo_Challenge', 'timestamp': 'Mar 25, 2020, 1:26 PM'}
#
# {'user': '57', 'post': 'ঈদ মোবারক!🙃', 'timestamp': 'Mar 24, 2020, 10:20 AM'}
#
# {'user': '57', 'post': 'None', 'timestamp': '
PM'}
#
# {'user': '64', 'post': 'None', 'timestamp': 'Dec 5, 2020, 4:50 PM'}
#
# {'user': '64', 'post': 'None', 'timestamp': 'Dec 1, 2020, 4:49 PM'}
#
# ...
#
# {'user': '102', 'post': 'None', 'timestamp': '11 Dec 2015, 11:31'}
#
# {'user': '102', 'post': 'None', 'timestamp': '11 Dec 2015, 11:23'}
#
# {'user': '102', 'post': 'None', 'timestamp': '6 Dec 2015, 14:43'}
#
# {'user': '102', 'post': 'None', 'timestamp': '5 Dec 2015, 12:57'}
#
# {'user': '102', 'post': 'None', 'timestamp': '5 Dec 2015, 09:24'}
#
# {'user': '102', 'post': 'None', 'timestamp': '4 Dec 2015, 10:13'}
#
# {'user': '102', 'post': 'None', 'timestamp': '4 Dec 2015, 10:13'}
#
# {'user': '102', 'post': 'None', 'timestamp': '2 Dec 2015, 14:40'}
#
# {'user': '102', 'post': 'None', 'timestamp': '28 Nov 2015, 22:13'}
#
# {'user': '102', 'post': 'None', 'timestamp': '28 Nov 2015, 13:06'}
#
# {'user': '102', 'post': 'None', 'timestamp': '28 Nov 2015, 09:02'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Nov 2015, 14:53'}
#
# {'user': '102', 'post': 'None', 'timestamp': '16 Nov 2015, 14:42'}
#
# {'user': '102', 'post': 'None', 'timestamp': '16 Nov 2015, 14:42'}
#
# {'user': '102', 'post': 'None', 'timestamp': '13 Nov 2015, 21:21'}
#
# {'user': '102', 'post': 'None', 'timestamp': '7 Nov 2015, 16:20'}
#
# {'user': '102', 'post': 'None', 'timestamp': '6 Nov 2015, 12:33'}
#
# {'user': '102', 'post': 'None', 'timestamp': '5 Nov 2015, 15:45'}
#
# {'user': '102', 'post': 'None', 'timestamp': '4 Nov 2015, 14:54'}
#
# {'user': '102', 'post': 'None', 'timestamp': '3 Nov 2015, 11:35'}
#
# {'user': '102', 'post': 'None', 'timestamp': '3 Nov 2015, 11:34'}
#
# {'user': '102', 'post': 'None', 'timestamp': '31 Oct 2015, 17:46'}
#
# {'user': '102', 'post': 'None', 'timestamp': '31 Oct 2015, 10:44'}
#
# {'user': '102', 'post': 'None', 'timestamp': '31 Oct 2015, 10:44'}
#
# {'user': '102', 'post': 'None', 'timestamp': '30 Oct 2015, 13:53'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Oct 2015, 14:12'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Oct 2015, 13:57'}
#
# {'user': '102', 'post': 'None', 'timestamp': '23 Oct 2015, 18:43'}
#
# {'user': '102', 'post': 'None', 'timestamp': '21 Oct 2015, 12:55'}
#
# {'user': '102', 'post': 'None', 'timestamp': '19 Oct 2015, 23:11'}
#
# {'user': '102', 'post': 'None', 'timestamp': '19 Oct 2015, 22:55'}
#
# {'user': '102', 'post': 'None', 'timestamp': '19 Oct 2015, 15:03'}
#
# {'user': '102', 'post': 'None', 'timestamp': '15 Oct 2015, 10:01'}
#
# {'user': '102', 'post': 'None', 'timestamp': '14 Oct 2015, 15:45'}
#
# {'user': '102', 'post': 'None', 'timestamp': '12 Oct 2015, 15:07'}
#
# {'user': '102', 'post': 'None', 'timestamp': '10 Oct 2015, 22:11'}
#
# {'user': '102', 'post': 'None', 'timestamp': '9 Oct 2015, 14:00'}
#
# {'user': '102', 'post': 'None', 'timestamp': '6 Oct 2015, 15:37'}
#
# {'user': '102', 'post': 'None', 'timestamp': '3 Oct 2015, 09:09'}
#
# {'user': '102', 'post': 'None', 'timestamp': '1 Oct 2015, 18:43'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Sep 2015, 08:42'}
#
# {'user': '102', 'post': 'None', 'timestamp': '24 Sep 2015, 21:49'}
#
# {'user': '102', 'post': 'None', 'timestamp': '22 Sep 2015, 10:06'}
#
# {'user': '102', 'post': 'None', 'timestamp': '18 Sep 2015, 23:12'}
#
# {'user': '102', 'post': 'None', 'timestamp': '17 Sep 2015, 21:58'}
#
# {'user': '102', 'post': 'None', 'timestamp': '15 Sep 2015, 21:32'}
#
# {'user': '102', 'post': 'None', 'timestamp': '12 Sep 2015, 17:24'}
#
# {'user': '102', 'post': 'None', 'timestamp': '10 Sep 2015, 08:27'}
#
# {'user': '102', 'post': 'None', 'timestamp': '10 Sep 2015, 08:17'}
#
# {'user': '102', 'post': 'None', 'timestamp': '2 Sep 2015, 10:29'}
#
# {'user': '102', 'post': 'None', 'timestamp': '31 Aug 2015, 08:11'}
#
# {'user': '102', 'post': 'None', 'timestamp': '28 Aug 2015, 17:13'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Aug 2015, 15:36'}
#
# {'user': '102', 'post': 'None', 'timestamp': '22 Aug 2015, 15:30'}
#
# {'user': '102', 'post': 'None', 'timestamp': '16 Aug 2015, 14:47'}
#
# {'user': '102', 'post': 'None', 'timestamp': '2 Aug 2015, 18:28'}
#
# {'user': '102', 'post': '☺☺☺', 'timestamp': '2 Aug 2015, 17:53'}
#
# {'user': '102', 'post': 'None', 'timestamp': '31 Jul 2015, 17:38'}
#
# {'user': '102', 'post': 'None', 'timestamp': '30 Jul 2015, 16:49'}
#
# {'user': '102', 'post': 'None', 'timestamp': '30 Jul 2015, 16:43'}
#
# {'user': '102', 'post': 'None', 'timestamp': '29 Jul 2015, 14:41'}
#
# {'user': '102', 'post': 'None', 'timestamp': '26 Jul 2015, 17:37'}
#
# {'user': '102', 'post': 'None', 'timestamp': '26 Jul 2015, 17:30'}
#
# {'user': '102', 'post': 'None', 'timestamp': '26 Jul 2015, 16:48'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Jul 2015, 19:59'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Jul 2015, 14:32'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Jul 2015, 14:17'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Jul 2015, 14:04'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Jul 2015, 14:03'}
#
# {'user': '102', 'post': 'None', 'timestamp': '25 Jul 2015, 14:00'}
#
# {'user': '102', 'post': 'None', 'timestamp': '22 Jul 2015, 10:18'}
#
# {'user': '102', 'post': 'None', 'timestamp': '21 Jul 2015, 11:25'}
#
# {'user': '102', 'post': 'None', 'timestamp': '21 Jul 2015, 11:25'}
#
# {'user': '102', 'post': 'None', 'timestamp': '16 Jul 2015, 01:39'}
#
# {'user': '102', 'post': 'None', 'timestamp': '15 Jul 2015, 13:19'}
#
# {'user': '102', 'post': 'None', 'timestamp': '14 Jul 2015, 11:04'}
#
# {'user': '102', 'post': 'None', 'timestamp': '13 Jul 2015, 22:44'}
#
# {'user': '102', 'post': 'None', 'timestamp': '8 Jul 2015, 14:49'}
#
# {'user': '102', 'post': 'None', 'timestamp': '8 Jul 2015, 14:41'}
#
# {'user': '102', 'post': 'None', 'timestamp': '6 Jul 2015, 22:15'}
#
# {'user': '102', 'post': 'None', 'timestamp': '4 Jul 2015, 20:54'}
#
# {'user': '102', 'post': 'None', 'timestamp': '1 Jul 2015, 15:39'}
#
# {'user': '102', 'post': 'None', 'timestamp': '30 Jun 2015, 22:18'}
#
# {'user': '102', 'post': 'None', 'timestamp': '30 Jun 2015, 14:59'}
#
# {'user': '102', 'post': 'None', 'timestamp': '29 Jun 2015, 23:09'}
#
# {'user': '102', 'post': 'None', 'timestamp': '29 Jun 2015, 22:09'}
#
# {'user': '102', 'post': 'None', 'timestamp': '29 Jun 2015, 12:25'}
#
# {'user': '102', 'post': 'None', 'timestamp': '28 Jun 2015, 10:21'}
#
# {'user': '102', 'post': 'None', 'timestamp': '27 Jun 2015, 10:56'}
#
# {'user': '102', 'post': 'Hai re!!!!!', 'timestamp': '26 Jun 2015, 19:32'}
#
# {'user': '102', 'post': 'None', 'timestamp': '26 Jun 2015, 10:05'}
#
# {'user': '102', 'post': 'Happy Birth Day Leonal Messi /LM10 /Best player', 'timestamp': '24 Jun 2015, 11:44'}
#
# {'user': '102', 'post': 'None', 'timestamp': '18 May 2015, 11:12'}
#
# {'user': '102', 'post': 'None', 'timestamp': '14 May 2015, 00:40'}
#
# {'user': '102', 'post': 'None', 'timestamp': '12 May 2015, 15:30'}
#
# {'user': '102', 'post': 'None', 'timestamp': '28 Apr 2015, 15:50'}
#
# {'user': '102', 'post': 'None', 'timestamp': '3 Apr 2015, 20:50'}
#
# {'user': '102', 'post': 'None', 'timestamp': '22 Mar 2015, 16:49'}
#
# {'user': '102', 'post': 'None', 'timestamp': '22 Mar 2015, 10:46'}
#
# {'user': '102', 'post': 'None', 'timestamp': '30 Oct 2014, 11:43'}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 29, 2020, 9:47 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 28, 2020, 10:12 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 27, 2020, 11:13 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 27, 2020, 6:32 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 26, 2020, 11:13 AM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 25, 2020, 4:19 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 23, 2020, 9:01 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 21, 2020, 9:10 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 19, 2020, 7:05 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 18, 2020, 8:20 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 16, 2020, 8:21 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 11, 2020, 9:25 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 3, 2020, 12:23 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Dec 2, 2020, 5:13 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 26, 2020, 5:18 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 26, 2020, 7:55 AM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 23, 2020, 10:05 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 16, 2020, 6:04 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 14, 2020, 3:33 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 9, 2020, 7:32 AM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 8, 2020, 2:28 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 4, 2020, 9:18 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 3, 2020, 11:28 AM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 2, 2020, 5:56 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 2, 2020, 5:53 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Nov 1, 2020, 10:05 PM'}
#
# {'user': '89', 'post': 'None', 'timestamp': 'Oct
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# Group activities Scraper

# %%
# Opening the html file. If the file
# is present in different location, 
# exact location need to be mentioned

for user in users_list: # goes through each user in the folder
  groups_filedir = f"/content/users/{user}/groups/your_posts_and_comments_in_groups.html"
  HTMLFileToBeOpened = codecs.open(groups_filedir, "r", "utf-8") # use codecs.open to open html files!
    
  # Reading the file and storing in a variable
  contents = HTMLFileToBeOpened.read()
    
  # Creating a BeautifulSoup object and
  # specifying the parser 
  soup = BeautifulSoup(contents, 'lxml')


  group_comments_list = []
  posts_list = []
  substring_group = 'Group:'

  for span in soup("span"):
    span.clear()
  for div in soup.find_all("div", {'class':'_3-95'}): 
      children = div.findChildren("div", recursive=False)
      for child in children:
        for child_div in child.find_all("div", {'class':'_3-95'}):
          child_div.clear()
        # print(child)

  for content in soup.find_all("div", class_="pam"): # content div of each comment
      # print(content,'\n')
      text = content.find("div", class_="_2pin").get_text() if content.find("div", class_="_2pin") else "None" # post text
      
      content_dict = {} # create a dictionary for each comment section
      content_dict['user'] = user # create 41 as user id
      content_dict['post'] = content.find("div", class_="_2pin").get_text() if content.find("div", class_="_2pin") else "None" # post text
      content_dict['post'] = content_dict['post'].replace('\n', ' ') # removes \n from post
      content_dict['timestamp'] = content.find("div", class_="_3-94").get_text() # comments timestamp

      if substring_group in text: # if its a group comment
          # print('group')
          group_comments_list.append(content_dict)
      else:
          # print('NOT group')
          posts_list.append(content_dict)


  for i in group_comments_list:
      print(i,'\n')

  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  for i in posts_list:
      print(i,'\n')
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {'user': '41', 'post': '', 'timestamp': 'Jan 8, 2021, 2:28 PM'}
#
# {'user': '41', 'post': '', 'timestamp': 'Jan 8, 2021, 2:26 PM'}
#
# {'user': '41', 'post': '', 'timestamp': 'Jan 8, 2021, 2:25 PM'}
#
# {'user': '41', 'post': '', 'timestamp': 'Jan 8, 2021, 2:18 PM'}
#
# {'user': '41', 'post': 'ভাই আপনার বিয়ে এমনেও হবে না', 'timestamp': 'Jan 7, 2021, 11:38 AM'}
#
# {'user': '41', 'post': 'ভাই আপনার বিয়ে এমনেও হবে না', 'timestamp': 'Jan 7, 2021, 11:38 AM'}
#
# {'user': '41', 'post': 'Israt Jahan  ', 'timestamp': 'Jan 5, 2021, 1:56 PM'}
#
# {'user': '41', 'post': 'Israt Jahan  ', 'timestamp': 'Jan 5, 2021, 1:56 PM'}
#
# {'user': '41', 'post': 'Ki problem?', 'timestamp': 'Jan 4, 2021, 7:31 PM'}
#
# {'user': '41', 'post': 'Ki problem?', 'timestamp': 'Jan 4, 2021, 7:31 PM'}
#
# {'user': '41', 'post': 'বগুড়া বানান ভুল।', 'timestamp': 'Dec 26, 2020, 11:29 AM'}
#
# {'user': '41', 'post': 'বগুড়া বানান ভুল।', 'timestamp': 'Dec 26, 2020, 11:29 AM'}
#
# {'user': '41', 'post': 'BRTC kon post e?', 'timestamp': 'Dec 24, 2020, 10:12 PM'}
#
# {'user': '41', 'post': 'BRTC kon post e?', 'timestamp': 'Dec 24, 2020, 10:12 PM'}
#
# {'user': '41', 'post': 'ডাক্তারের পরামর্শ ছাড়া এসব ঔষধ না খাওয়াই ভাল, প্রতিক্রিয়া হতে পারে।', 'timestamp': 'Dec 23, 2020, 1:28 PM'}
#
# {'user': '41', 'post': 'ডাক্তারের পরামর্শ ছাড়া এসব ঔষধ না খাওয়াই ভাল, প্রতিক্রিয়া হতে পারে।', 'timestamp': 'Dec 23, 2020, 1:28 PM'}
#
# {'user': '41', 'post': 'সুইসাইড করলে বইলেন', 'timestamp': 'Dec 21, 2020, 1:03 AM'}
#
# {'user': '41', 'post': 'সুইসাইড করলে বইলেন', 'timestamp': 'Dec 21, 2020, 1:03 AM'}
#
# {'user': '41', 'post': 'scholarship er jonno apnar university te contact korai better hobe, r daffodil e fixed credit so semester drop dile apnar frndsder sathe r class korte parben na. aita aktu problem hote pare', 'timestamp': 'Dec 20, 2020, 6:46 PM'}
#
# {'user': '41', 'post': 'scholarship er jonno apnar university te contact korai better hobe, r daffodil e fixed credit so semester drop dile apnar frndsder sathe r class korte parben na. aita aktu problem hote pare', 'timestamp': 'Dec 20, 2020, 6:46 PM'}
#
# {'user': '41', 'post': 'Kon university?', 'timestamp': 'Dec 20, 2020, 3:51 PM'}
#
# {'user': '41', 'post': 'Kon university?', 'timestamp': 'Dec 20, 2020, 3:51 PM'}
#
# {'user': '41', 'post': 'tk khujle forsa tou khujbei', 'timestamp': 'Dec 19, 2020, 1:30 PM'}
#
# {'user': '41', 'post': 'tk khujle forsa tou khujbei', 'timestamp': 'Dec 19, 2020, 1:30 PM'}
#
# {'user': '41', 'post': 'Paru Sahara apni ki system niye kaj koren', 'timestamp': 'Dec 18, 2020, 1:16 PM'}
#
# {'user': '41', 'post': 'Paru Sahara apni ki system niye kaj koren', 'timestamp': 'Dec 18, 2020, 1:16 PM'}
#
# {'user': '41', 'post': 'Bhaia BBA pore system engineer, aktu bujhiye bolben?', 'timestamp': 'Dec 18, 2020, 12:43 PM'}
#
# {'user': '41', 'post': 'Bhaia BBA pore system engineer, aktu bujhiye bolben?', 'timestamp': 'Dec 18, 2020, 12:43 PM'}
#
# {'user': '41', 'post': 'Towhid Salahuddin Bhaia I am talking about Apple ID not billing address', 'timestamp': 'Dec 16, 2020, 3:40 PM'}
#
# {'user': '41', 'post': 'Towhid Salahuddin Bhaia I am talking about Apple ID not billing address', 'timestamp': 'Dec 16, 2020, 3:40 PM'}
#
# {'user': '41', 'post': 'Amar apple id Bangladeshi phone number diye khola, Two step verification code amr Bangladeshi phone number ai ase', 'timestamp': 'Dec 16, 2020, 2:00 PM'}
#
# {'user': '41', 'post': 'Amar apple id Bangladeshi phone number diye khola, Two step verification code amr Bangladeshi phone number ai ase', 'timestamp': 'Dec 16, 2020, 2:00 PM'}
#
# {'user': '41', 'post': 'কে বলছে খোলা যায়না???', 'timestamp': 'Dec 16, 2020, 1:37 PM'}
#
# {'user': '41', 'post': 'কে বলছে খোলা যায়না???', 'timestamp': 'Dec 16, 2020, 1:37 PM'}
#
# {'user': '41', 'post': "Please don't use any keyboard protector", 'timestamp': 'Dec 13, 2020, 3:38 PM'}
#
# {'user': '41', 'post': "Please don't use any keyboard protector", 'timestamp': 'Dec 13, 2020, 3:38 PM'}
#
# {'user': '41', 'post': 'আপনারা কি একাধিক গভীর দূধ একসাথে মিশান না?', 'timestamp': 'Dec 13, 2020, 3:23 PM'}
#
# {'user': '41', 'post': 'আপনারা কি একাধিক গভীর দূধ একসাথে মিশান না?', 'timestamp': 'Dec 13, 2020, 3:23 PM'}
#
# {'user': '41', 'post': 'এই দুঃসংবাদ না জানালেও পারতা 😔', 'timestamp': 'Dec 12, 2020, 8:21 PM'}
#
# {'user': '41', 'post': 'এই দুঃসংবাদ না জানালেও পারতা 😔', 'timestamp': 'Dec 12, 2020, 8:21 PM'}
#
# {'user': '41', 'post': 'বলছি দাঁত সুন্দর 😬', 'timestamp': 'Dec 12, 2020, 7:50 PM'}
#
# {'user': '41', 'post': 'বলছি দাঁত সুন্দর 😬', 'timestamp': 'Dec 12, 2020, 7:50 PM'}
#
# {'user': '41', 'post': 'আই লাভ দিস দাঁতের পাটি 🐸', 'timestamp': 'Dec 12, 2020, 7:42 PM'}
#
# {'user': '41', 'post': 'আই লাভ দিস দাঁতের পাটি 🐸', 'timestamp': 'Dec 12, 2020, 7:42 PM'}
#
# {'user': '41', 'post': 'Rag korar moto kisu bolini, housing limited e  khal ache ', 'timestamp': 'Dec 12, 2020, 5:08 PM'}
#
# {'user': '41', 'post': 'Rag korar moto kisu bolini, housing limited e  khal ache ', 'timestamp': 'Dec 12, 2020, 5:08 PM'}
#
# {'user': '41', 'post': 'আপনার বাসা কি খালের পাশে?', 'timestamp': 'Dec 12, 2020, 12:30 PM'}
#
# {'user': '41', 'post': 'আপনার বাসা কি খালের পাশে?', 'timestamp': 'Dec 12, 2020, 12:30 PM'}
#
# {'user': '41', 'post': 'I am a story teller but no one listen 😔', 'timestamp': 'Dec 12, 2020, 12:40 AM'}
#
# {'user': '41', 'post': 'I am a story teller but no one listen 😔', 'timestamp': 'Dec 12, 2020, 12:40 AM'}
#
# {'user': '41', 'post': 'Suzuki, Yahama, Honda sob bike e ki unar?', 'timestamp': 'Dec 11, 2020, 3:06 PM'}
#
# {'user': '41', 'post': 'Suzuki, Yahama, Honda sob bike e ki unar?', 'timestamp': 'Dec 11, 2020, 3:06 PM'}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {'user': '24', 'post': 'Updated Dec 6, 2020, 7:35 PM', 'timestamp': 'Dec 6, 2020, 7:35 PM'}
#
# {'user': '24', 'post': 'Updated Dec 6, 2020, 7:58 PMPublished on Dec 6, 2020, 7:58 PM', 'timestamp': 'Dec 6, 2020, 7:24 PM'}
#
# {'user': '24', 'post': 'Interested', 'timestamp': 'Oct 9, 2020, 2:04 PM'}
#
# {'user': '24', 'post': 'Interested', 'timestamp': 'Oct 9, 2020, 2:04 PM'}
#
# {'user': '24', 'post': 'Interested, please let me know the details', 'timestamp': 'Oct 9, 2020, 2:03 PM'}
#
# {'user': '24', 'post': 'Interested, please let me know the details', 'timestamp': 'Oct 9, 2020, 2:03 PM'}
#
# {'user': '24', 'post': 'Ian Eveleigh i use it on a fringer adpater (mk II). They have added support for phase detect through this lens last fall via firmware upgrade. The autofocus speed is more than adequate and reliably locks in. What attracted me the most about this lens is its corner to corner sharpness. The build quality is just a bonus. Mine came in pretty much unused condition, no scratch and intact coatings. The lens was initially front heavy. But after installing an aftermarket grip the handling is now fantastic.', 'timestamp': 'Aug 6, 2020, 3:27 PM'}
#
# {'user': '24', 'post': 'Ian Eveleigh i use it on a fringer adpater (mk II). They have added support for phase detect through this lens last fall via firmware upgrade. The autofocus speed is more than adequate and reliably locks in. What attracted me the most about this lens is its corner to corner sharpness. The build quality is just a bonus. Mine came in pretty much unused condition, no scratch and intact coatings. The lens was initially front heavy. But after installing an aftermarket grip the handling is now fantastic.', 'timestamp': 'Aug 6, 2020, 3:27 PM'}
#
# {'user': '24', 'post': "I have been using a sigma 8-16 (purchased second hand for $220) for couple of years with my fuji x-t1. Couldn't be happier with sharpness and range.", 'timestamp': 'Aug 6, 2020, 1:26 PM'}
#
# {'user': '24', 'post': "I have been using a sigma 8-16 (purchased second hand for $220) for couple of years with my fuji x-t1. Couldn't be happier with sharpness and range.", 'timestamp': 'Aug 6, 2020, 1:26 PM'}
#
# {'user': '24', 'post': 'Could you show us the rear elemenr? I am quite curious about the weird bokeh balls!', 'timestamp': 'Jul 24, 2020, 1:50 AM'}
#
# {'user': '24', 'post': 'Could you show us the rear elemenr? I am quite curious about the weird bokeh balls!', 'timestamp': 'Jul 24, 2020, 1:50 AM'}
#
# {'user': '24', 'post': 'https://bdren.zoom.us/j/68884203361', 'timestamp': 'Jul 19, 2020, 12:52 PM'}
#
# {'user': '24', 'post': 'Group 4, please join the meeting.', 'timestamp': 'Jul 19, 2020, 12:11 PM'}
#
# {'user': '24', 'post': 'Group 4, please join the meeting.', 'timestamp': 'Jul 19, 2020, 12:11 PM'}
#
# {'user': '24', 'post': 'https://bdren.zoom.us/j/61921072412', 'timestamp': 'Jul 18, 2020, 9:21 PM'}
#
# {'user': '24', 'post': 'of course. on or after 7th july.', 'timestamp': 'Jun 30, 2020, 10:41 PM'}
#
# {'user': '24', 'post': 'of course. on or after 7th july.', 'timestamp': 'Jun 30, 2020, 10:41 PM'}
#
# {'user': '24', 'post': 'This is to notify for all that the Makeup Mid-term & Final Examinations of Spring Semester 2020 will be held from 15th July to 19th July 2020 using an online platform. Students who’s Mid- term Examinations could not be held for closure of the university due to Covid-19 and students who have missed the Midterm or the Final Examinations of any course or any component (Assignment/Viva-Voce) of any course in the Final Examination will be eligible to appear at the makeup examinations. The academic departments are requested to declare the schedule of the makeup examinations by 7th July 2020. Accordingly, the respected course teachers will communicate the concerned students the syllabus, assignment and viva-voce topics. Students who missed the midterm or the final examination of any course that had already been held are requested to follow the instructions of the department and the course teacher to appear in the makeup examination. No form fill up or payments will be required this time as part of special consideration for the students due to COVID-19.Updated Jun 30, 2020, 10:51 PM', 'timestamp': 'Jun 30, 2020, 9:12 PM'}
#
# {'user': '24', 'post': 'https://drive.google.com/open?id=1u_xyp0SuxUu4zYLifQbJsgiIRZCLL7Mm', 'timestamp': 'Jun 10, 2020, 8:45 PM'}
#
# {'user': '24', 'post': 'Please mention your course code and assignment number in the subject of your mail. I wont be able to grade you if the subject line or the body of your email is empty.Updated Jun 3, 2020, 8:13 PM', 'timestamp': 'Jun 3, 2020, 8:13 PM'}
#
# {'user': '24', 'post': 'https://bdren.zoom.us/j/188049618', 'timestamp': 'May 31, 2020, 6:58 PM'}
#
# {'user': '24', 'post': 'Hi, hope you are doing well. As you may already know, you are going to be graded through online viva and assignment. We need to discuss and set a strategy to conduct this drill successfully. Please discuss with your CR Emran Hossain Emu and set a suitable time for us to have a meeting tomorrow.Updated May 21, 2020, 12:13 PM', 'timestamp': 'May 21, 2020, 12:13 PM'}
#
# {'user': '24', 'post': 'please keep urself available from 10:30AM to 1:00PM tomorrow. After i text you,use the ID below to join our meeting,  Meeting ID: 987 584 0678Updated May 13, 2020, 12:12 AM', 'timestamp': 'May 13, 2020, 12:12 AM'}
#
# {'user': '24', 'post': 'https://bdren.zoom.us/rec/share/-pBtNLCt1l5IfKv17UfEC5UGDqL5eaa81CQW_qVczhqNsAttZ_MQx7RvNZ5N7R-P?startTime=1589297451000', 'timestamp': 'May 12, 2020, 11:46 PM'}
#
# {'user': '24', 'post': 'agamikal shokale meet korbo amra @11am ', 'timestamp': 'May 8, 2020, 10:37 AM'}
#
# {'user': '24', 'post': 'agamikal shokale meet korbo amra @11am ', 'timestamp': 'May 8, 2020, 10:37 AM'}
#
# {'user': '24', 'post': 'Lets meet next Saturday (2-05-20). Pick a suitable time for the meeting.Updated May 8, 2020, 10:37 AM', 'timestamp': 'Apr 30, 2020, 12:19 PM'}
#
# {'user': '24', 'post': 'https://www.youtube.com/playlist?list=PLucBqxKJDEdXKEKyotIjvIStHstTxM0Iz', 'timestamp': 'Apr 13, 2020, 10:54 AM'}
#
# {'user': '24', 'post': 'Thanks emon. minor corrections to the following points: 3. 3-Lead ECG 5. Cardiac Leads 12. CMRR (Common mode rejection ratio)', 'timestamp': 'Apr 12, 2020, 10:12 PM'}
#
# {'user': '24', 'post': 'Thanks emon. minor corrections to the following points: 3. 3-Lead ECG 5. Cardiac Leads 12. CMRR (Common mode rejection ratio)', 'timestamp': 'Apr 12, 2020, 10:12 PM'}
#
# {'user': '24', 'post': 'https://bdren.zoom.us/j/188049618', 'timestamp': 'Apr 12, 2020, 10:06 PM'}
#
# {'user': '24', 'post': '623 290 730, waiting', 'timestamp': 'Apr 12, 2020, 8:03 PM'}
#
# {'user': '24', 'post': '623 290 730, waiting', 'timestamp': 'Apr 12, 2020, 8:03 PM'}
#
# {'user': '24', 'post': 'https://www.youtube.com/watch?v=kwLbSx9BNbU', 'timestamp': 'Apr 12, 2020, 6:21 PM'}
#
# {'user': '24', 'post': 'https://www.youtube.com/watch?v=aCZWA72w5Jk', 'timestamp': 'Apr 12, 2020, 6:21 PM'}
#
# {'user': '24', 'post': 'Hope everyone is doing well. Lets have a meeting tomorrow. Is 8:00PM ok?Updated Apr 12, 2020, 8:03 PM', 'timestamp': 'Apr 11, 2020, 9:52 PM'}
#
# {'user': '24', 'post': 'Shishir Paul ami daraz e ekta deal paisi, 800 for moonman m2 fine nib. apner ki mone hoy eta valo deal?', 'timestamp': 'Apr 10, 2020, 10:59 PM'}
#
# {'user': '24', 'post': 'Shishir Paul ami daraz e ekta deal paisi, 800 for moonman m2 fine nib. apner ki mone hoy eta valo deal?', 'timestamp': 'Apr 10, 2020, 10:59 PM'}
#
# {'user': '24', 'post': 'Shishir Paul koto cost porse apner EF er jonno? Ami pilot Kakuno fine nib use kori, amar kase onk scratchy mone hoy lekhar shomoy. moonman er EF scratch kore kemn?', 'timestamp': 'Apr 10, 2020, 10:53 PM'}
#
# {'user': '24', 'post': 'Shishir Paul koto cost porse apner EF er jonno? Ami pilot Kakuno fine nib use kori, amar kase onk scratchy mone hoy lekhar shomoy. moonman er EF scratch kore kemn?', 'timestamp': 'Apr 10, 2020, 10:53 PM'}
#
# {'user': '24', 'post': 'i have been considering moonman M2 as my next purchase. can you give me a brief review?', 'timestamp': 'Apr 10, 2020, 10:43 PM'}
#
# {'user': '24', 'post': 'i have been considering moonman M2 as my next purchase. can you give me a brief review?', 'timestamp': 'Apr 10, 2020, 10:43 PM'}
#
# {'user': '24', 'post': 'https://youtu.be/H3s_er2RVzwUpdated Apr 6, 2020, 1:10 PM', 'timestamp': 'Apr 6, 2020, 1:10 PM'}
#
# {'user': '24', 'post': 'Download file: files/Thesis_Presentation_2593522740861741.ppsx', 'timestamp': 'Apr 5, 2020, 12:14 AM'}
#
# {'user': '24', 'post': 'https://www.youtube.com/watch?v=oa6rvUJlg7o', 'timestamp': 'Apr 4, 2020, 9:33 PM'}
#
# {'user': '24', 'post': 'https://www.youtube.com/watch?v=FEHNIELPb0s&t=138s', 'timestamp': 'Apr 4, 2020, 9:32 PM'}
#
# {'user': '24', 'post': 'Waiting for u guys to joinUpdated Apr 4, 2020, 8:33 PM', 'timestamp': 'Apr 4, 2020, 8:33 PM'}
#
# {'user': '24', 'post': 'https://bdren.zoom.us/j/623290730', 'timestamp': 'Apr 4, 2020, 3:11 PM'}
#
# {'user': '24', 'post': 'Let us have a meeting tomorrow. Please make sure to learn more about the following topics before attending the meeting: 1. What is Electrocardiogram? 1. What is the source of ECG? 1. What are the different probe configuration conventional ECG utilizes?Updated Apr 3, 2020, 11:08 AM', 'timestamp': 'Apr 3, 2020, 11:08 AM'}
#
# {'user': '24', 'post': 'https://www.researchgate.net/publication/336767330_A_Nanofluidic_Memristor_Based_on_Ion_Concentration_Polarization', 'timestamp': 'Apr 1, 2020, 11:39 AM'}
#
# {'user': '24', 'post': 'https://www.researchgate.net/publication/336767330_A_Nanofluidic_Memristor_Based_on_Ion_Concentration_Polarization', 'timestamp': 'Apr 1, 2020, 11:39 AM'}
#
# {'user': '24', 'post': 'https://www.elprocus.com/what-is-a-memristor-types-of-memristors-and-their-applications/', 'timestamp': 'Apr 1, 2020, 11:38 AM'}
#
# {'user': '24', 'post': 'https://www.elprocus.com/what-is-a-memristor-types-of-memristors-and-their-applications/', 'timestamp': 'Apr 1, 2020, 11:38 AM'}
#
# {'user': '24', 'post': 'https://www.youtube.com/watch?v=LUEtKqH6bws&feature=youtu.be', 'timestamp': 'Apr 1, 2020, 11:38 AM'}
#
# {'user': '24', 'post': 'https://www.youtube.com/watch?v=KSylo01n5FY', 'timestamp': 'Apr 1, 2020, 10:08 AM'}
#
# {'user': '24', 'post': 'আমি উপযুক্ত কর্তৃপক্ষের সাথে আলাপ করে আপনাকে এই বিষয়ে জানাব।', 'timestamp': 'Mar 30, 2020, 8:57 PM'}
#
# {'user': '24', 'post': 'আমি উপযুক্ত কর্তৃপক্ষের সাথে আলাপ করে আপনাকে এই বিষয়ে জানাব।', 'timestamp': 'Mar 30, 2020, 8:57 PM'}
#
# {'user': '24', 'post': 'Load shedding 😅 please discuss among urselves and fix the schedule. Let me know ur decision here. Stay safe, see u in the next class 🖐Updated Mar 30, 2020, 8:57 PM', 'timestamp': 'Mar 30, 2020, 9:01 AM'}
#
# {'user': '24', 'post': 'https://bdren.zoom.us/j/807016735', 'timestamp': 'Mar 29, 2020, 10:27 PM'}
#
# {'user': '24', 'post': 'Mirza Emon yes, if theres any problem joining the meeting room please let me know here', 'timestamp': 'Mar 29, 2020, 12:13 PM'}
#
# {'user': '24', 'post': 'Mirza Emon yes, if theres any problem joining the meeting room please let me know here', 'timestamp': 'Mar 29, 2020, 12:13 PM'}
#
# {'user': '24', 'post': 'Meeting ID: 386 939 1035 Password: ECG', 'timestamp': 'Mar 29, 2020, 12:09 PM'}
#
# {'user': '24', 'post': 'Meeting ID: 386 939 1035 Password: ECG', 'timestamp': 'Mar 29, 2020, 12:09 PM'}
#
# {'user': '24', 'post': 'How about we arrange to meet tonight at 8:30pm?', 'timestamp': 'Mar 29, 2020, 11:33 AM'}
#
# {'user': '24', 'post': 'How about we arrange to meet tonight at 8:30pm?', 'timestamp': 'Mar 29, 2020, 11:33 AM'}
#
# {'user': '24', 'post': 'Hi Class. Hows quarantine life treating you? I hope all of you are eagerly waiting to get back to your normal lives. I am very pleased to know that you are very enthusiastic about continuing this semester through online classes. Emran Hossain Emu has already informed me that, you guys would like to take EEE 201 classes on regular schedule ( monday and wednesday 8:30 am). Please let me know if we can arrange the first class on this monday. (p.s. it will be a demo class and we will just have a good chat).Updated Mar 28, 2020, 10:20 PM', 'timestamp': 'Mar 28, 2020, 10:20 PM'}
#
# {'user': '24', 'post': 'after Maghrib or Esha, both are fine for me.', 'timestamp': 'Mar 27, 2020, 9:02 PM'}
#
# {'user': '24', 'post': 'after Maghrib or Esha, both are fine for me.', 'timestamp': 'Mar 27, 2020, 9:02 PM'}
#
# {'user': '24', 'post': 'Hope you are doing well. Lets have an online meeting on sunday. Could you let me know convenient time for the meeting?Updated Mar 29, 2020, 4:31 PM', 'timestamp': 'Mar 27, 2020, 8:30 PM'}
#
# {'user': '24', 'post': 'Do u have any red ink in your stock?', 'timestamp': 'Mar 17, 2020, 7:33 PM'}
#
# {'user': '24', 'post': 'Do u have any red ink in your stock?', 'timestamp': 'Mar 17, 2020, 7:33 PM'}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {'user': '90', 'post': 'Tasnim Riya pp?', 'timestamp': '30 Dec 2020, 12:22'}
#
# {'user': '90', 'post': 'Tasnim Riya pp?', 'timestamp': '30 Dec 2020, 12:22'}
#
# {'user': '90', 'post': 'Tasnim Riya pp?', 'timestamp': '30 Dec 2020, 12:22'}
#
# {'user': '90', 'post': 'Tasnim Riya pp?', 'timestamp': '30 Dec 2020, 12:22'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni', 'timestamp': '30 Dec 2020, 11:17'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni', 'timestamp': '30 Dec 2020, 11:17'}
#
# {'user': '90', 'post': 'boycott_comando_movie  #boycott_dev #boycott_shapla_media #boycott_salim_khan #Boycott_shamim_ahmed_roni', 'timestamp': '29 Dec 2020, 12:49'}
#
# {'user': '90', 'post': 'boycott_comando_movie  #boycott_dev #boycott_shapla_media #boycott_salim_khan #Boycott_shamim_ahmed_roni', 'timestamp': '29 Dec 2020, 12:49'}
#
# {'user': '90', 'post': 'boycott_comando_movie  #boycott_dev #boycott_shapla_media #boycott_salim_khan #Boycott_shamim_ahmed_roni', 'timestamp': '29 Dec 2020, 12:49'}
#
# {'user': '90', 'post': 'boycott_comando_movie  #boycott_dev #boycott_shapla_media #boycott_salim_khan #Boycott_shamim_ahmed_roni', 'timestamp': '29 Dec 2020, 12:49'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:38'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:38'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:38'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:38'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:38'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:38'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:37'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:37'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:37'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:37'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:37'}
#
# {'user': '90', 'post': '#Boycott_Dev #Boycott_Commando_Movie #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni #we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '28 Dec 2020, 11:37'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:56'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:56'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#বয়কট_কমান্ডো_মুভি #Boycott_Comando_Movie #Boycott_Dev #Boycott_Shapla_Media #Boycott_Salim_Khan #Boycott_Shamim_Ahmed_Roni ©️', 'timestamp': '28 Dec 2020, 10:55'}
#
# {'user': '90', 'post': '#we_love_Muhammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_Muhammadur_rasulullah #we_love_mohammad_ﷺ_challenge\ufeff', 'timestamp': '28 Dec 2020, 10:54'}
#
# {'user': '90', 'post': '#we_love_Muhammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_Muhammadur_rasulullah #we_love_mohammad_ﷺ_challenge\ufeff', 'timestamp': '28 Dec 2020, 10:54'}
#
# {'user': '90', 'post': '#Boycott_Dev  #Boycott_Comando_Movie  #Boycott_Shapla_Media #Boycott_Salim_khan  #Boycott_Shamim_Ahmed_Roni', 'timestamp': '28 Dec 2020, 10:53'}
#
# {'user': '90', 'post': '#Boycott_Dev  #Boycott_Comando_Movie  #Boycott_Shapla_Media #Boycott_Salim_khan  #Boycott_Shamim_Ahmed_Roni', 'timestamp': '28 Dec 2020, 10:53'}
#
# {'user': '90', 'post': 'R8', 'timestamp': '27 Dec 2020, 12:28'}
#
# {'user': '90', 'post': 'R8', 'timestamp': '27 Dec 2020, 12:28'}
#
# {'user': '90', 'post': 'Oyalaikom assalam', 'timestamp': '27 Dec 2020, 12:23'}
#
# {'user': '90', 'post': 'Oyalaikom assalam', 'timestamp': '27 Dec 2020, 12:23'}
#
# {'user': '90', 'post': 'Next', 'timestamp': '25 Dec 2020, 12:32'}
#
# {'user': '90', 'post': 'Next', 'timestamp': '25 Dec 2020, 12:32'}
#
# {'user': '90', 'post': 'Next', 'timestamp': '25 Dec 2020, 12:31'}
#
# {'user': '90', 'post': 'Next', 'timestamp': '25 Dec 2020, 12:31'}
#
# {'user': '90', 'post': '🤔🙄❤️🎂🤗', 'timestamp': '24 Dec 2020, 13:07'}
#
# {'user': '90', 'post': '🤔🙄❤️🎂🤗', 'timestamp': '24 Dec 2020, 13:07'}
#
# {'user': '90', 'post': '#we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '24 Dec 2020, 08:21'}
#
# {'user': '90', 'post': '#we_love_muhammad_ﷺ_challenge\ufeff\ufeff #we_love_mohammad_ﷺ_challenge\ufeff\ufeff   #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMuhammadﷺ #WeFollowMuhammadﷺ #WeAreUmmahOfMuhammadﷺ #WeHateFrancegovernment #LoveProphetMuhammadﷺ #MyProphetMyhonour #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Muhammad_ﷺ #We_Follow_Muhammad_ﷺ #We_Are_Ummah_of_Muhammad_ﷺ #Stop_Islam_phobia_In_France #We_Love_Mohammadﷺ #We_Follow_Mohammadﷺ #We_Are_Ummah_Of_Mohammadﷺ #Love_Prophet_Muhammad_ﷺ #My_Prophet_My_Honour #MyProphetMyPride #My_prophet_My_pride #WeLoveMohammadﷺ #WeFollowMohammadﷺ #WeAreUmmahOfMohammadﷺ #The_Dust_Will_Never_Settle_Down #La_ilaha_illallahu_muhammadur_rasulullah\u200e', 'timestamp': '24 Dec 2020, 08:21'}
#
# {'user': '90', 'post': 'Price?', 'timestamp': '23 Dec 2020, 19:14'}
#
# {'user': '90', 'post': 'Price?', 'timestamp': '23 Dec 2020, 19:14'}
#
# {'user': '90', 'post': 'Next', 'timestamp': '22 Dec 2020, 08:58'}
#
# {'user': '90', 'post': 'Next', 'timestamp': '22 Dec 2020, 08:58'}
#
# {'user': '90', 'post': 'Gg', 'timestamp': '20 Dec 2020, 16:18'}
#
# {'user': '90', 'post': 'Gg', 'timestamp': '20 Dec 2020, 16:18'}
#
# {'user': '90', 'post': 'Mehazabin Moni🤭🤣😂😅', 'timestamp': '5 Dec 2020, 23:43'}
#
# {'user': '90', 'post': 'Mehazabin Moni🤭🤣😂😅', 'timestamp': '5 Dec 2020, 23:43'}
#
# {'user': '90', 'post': 'Pp', 'timestamp': '4 Dec 2020, 16:52'}
#
# {'user': '90', 'post': 'Pp', 'timestamp': '4 Dec 2020, 16:52'}
#
# {'user': '90', 'post': 'Maliha Shabnam \U0001f90f🤭', 'timestamp': '4 Dec 2020, 16:43'}
#
# {'user': '90', 'post': 'Maliha Shabnam \U0001f90f🤭', 'timestamp': '4 Dec 2020, 16:43'}
#
# {'user': '90', 'post': '2017-2020', 'timestamp': '4 Dec 2020, 16:39'}
#
# {'user': '90', 'post': '2017-2020', 'timestamp': '4 Dec 2020, 16:39'}
#
# {'user': '90', 'post': 'Pp?', 'timestamp': '26 Nov 2020, 15:40'}
#
# {'user': '90', 'post': 'Pp?', 'timestamp': '26 Nov 2020, 15:40'}
#
# {'user': '90', 'post': '#we_love_mohammad_ﷺ_challenge\ufeff\ufeff  #Boycott_French_Products #Boycott_France_Products #Boycott_France #We_Love_Mohammad_ﷺ❤️ #We_Follow_Mohammad_ﷺ❤️ #We_Are_Ummah_of_prophet_Mohammad_SAW❤️ #We_Hate_France_government #We_Hate_French_President #CybarWaragainstFranch #boycot_france #Boycott_India #BoycottIndia #Love_Prophet_Muhammad_SAW ❤ #My_Prophet_My_Honour #For_our_beloved_Prophet #La_ilaha_illallahu_muhammadur_rasulullahSAW #BoycottFrenchProducts #welovemohammad_ﷺchallenge\ufeff\ufeff  #BoycottFrenchProducts #BoycottFranceProducts #BoycottFrance #WeLoveMohammadﷺ❤️ #WeFollowMohammadﷺ❤️ #WeAreUmm
we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge#we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge#we_love_Mohammad_ﷺ_challenge', 'timestamp': '1 Nov 2020, 16:35'}
#
# {'user': '90', 'post': '#we_love_Mohammad_ﷺ_challenge\ufeff  #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge#we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge#we_love_Mohammad_ﷺ_challenge', 'timestamp': '1 Nov 2020, 16:35'}
#
# {'user': '90', 'post': '#we_love_Mohammad_ﷺ_challenge\ufeff  #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge\ufeff #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge  #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge#we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge #we_love_Mohammad_ﷺ_challenge#we_love_Mohammad_ﷺ_challenge', 'timestamp': '1 Nov 2020, 16:34'}
#
# ...
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 3, 2020, 3:59 PM'}
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 3, 2020, 3:59 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:32 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:32 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:30 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:30 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:30 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:30 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:29 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:29 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:27 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 10:27 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:12 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:12 PM'}
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:11 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#we_love_mohammad_ﷺ_challenge', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:10 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFrench #BoycottFrenchProducts #WeLoveMuhammad(SAW) #WeFollowMuhammad(SAW) #LaIlahaIllallahuMuhammadurRasulullah #ShameOnPresidentOfFrance', 'timestamp': 'Nov 2, 2020, 6:07 PM'}
#
# {'user': '89', 'post': '#BoycottFranceProducts🚫 #BoycottFrance❎ #WeLoveMohammadﷺ❤️ #WeFollowMohammadﷺ❤️ #WeAreUmmahOfMohammadﷺ❤️ #WeHateFrancegovernment #boycotfrance❌ #ফ্রান্সপন্যবর্জনকরুন✖️ #LoveProphetMuhammadﷺ❤ #MyProphetMyHonour❤️ #Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:52 PM'}
#
# {'user': '89', 'post': '#BoycottFranceProducts🚫 #BoycottFrance❎ #WeLoveMohammadﷺ❤️ #WeFollowMohammadﷺ❤️ #WeAreUmmahOfMohammadﷺ❤️ #WeHateFrancegovernment #boycotfrance❌ #ফ্রান্সপন্যবর্জনকরুন✖️ #LoveProphetMuhammadﷺ❤ #MyProphetMyHonour❤️ #Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:52 PM'}
#
# {'user': '89', 'post': '#BoycottFranceProducts🚫 #BoycottFrance❎ #WeLoveMohammadﷺ❤️ #WeFollowMohammadﷺ❤️ #WeAreUmm
lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:48 PM'}
#
# {'user': '89', 'post': '#BoycottFranceProducts🚫 #BoycottFrance❎ #WeLoveMohammadﷺ❤️ #WeFollowMohammadﷺ❤️ #WeAreUmmahOfMohammadﷺ❤️ #WeHateFrancegovernment #boycotfrance❌ #ফ্রান্সপন্যবর্জনকরুন✖️ #LoveProphetMuhammadﷺ❤ #MyProphetMyHonour❤️ #Lailahaillallahumuhammadurrasulullahﷺ❤️', 'timestamp': 'Oct 30, 2020, 2:48 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 29, 2020, 12:54 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 29, 2020, 12:54 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 11:37 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 11:37 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:49 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:49 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:41 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:41 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:41 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:41 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:38 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 2:38 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:31 AM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:31 AM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:31 AM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:31 AM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:29 AM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 28, 2020, 12:29 AM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:55 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:55 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:50 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:50 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:49 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:49 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:48 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:48 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:34 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 27, 2020, 5:34 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 26, 2020, 10:43 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products', 'timestamp': 'Oct 26, 2020, 10:43 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products ', 'timestamp': 'Oct 26, 2020, 10:38 PM'}
#
# {'user': '89', 'post': '#Boycott_French_Products ', 'timestamp': 'Oct 26, 2020, 10:38 PM'}
#
# {'user': '89', 'post': 'Fake news vai', 'timestamp': 'Oct 26, 2020, 6:39 PM'}
#
# {'user': '89', 'post': 'Fake news vai', 'timestamp': 'Oct 26, 2020, 6:39 PM'}
#
# {'user': '89', 'post': 'Pi Al kon jaygay aida??🙄', 'timestamp': 'Sep 21, 2020, 6:06 PM'}
#
# {'user': '89', 'post': 'Pi Al kon jaygay aida??🙄', 'timestamp': 'Sep 21, 2020, 6:06 PM'}
#
# {'user': '89', 'post': 'Okk sir😍', 'timestamp': 'Aug 10, 2020, 10:53 PM'}
#
# {'user': '89', 'post': 'Okk sir😍', 'timestamp': 'Aug 10, 2020, 10:53 PM'}
#
# {'user': '89', 'post': 'Fahim Morshed Miajee haee vai, setai uchit chilo', 'timestamp': 'Jul 9, 2020, 8:08 PM'}
#
# {'user': '89', 'post': 'Fahim Morshed Miajee haee vai, setai uchit chilo', 'timestamp': 'Jul 9, 2020, 8:08 PM'}
#
# {'user': '89', 'post': 'The person who share this post যদি ওই মেয়ের জায়গায় আপনার নিজের বোন থাকতো তাইলে কি আপনি ঠিক এমন ভাবেই এই পোস্ট শেয়ার দিতেন? যদি উওর হয় না! তাইলে পরের বোনের এমন টাইপের ভিডিও শেয়ার দিলেন কেন???', 'timestamp': 'Jul 9, 2020, 3:46 PM'}
#
# {'user': '89', 'post': 'The person who share this post যদি ওই মেয়ের জায়গায় আপনার নিজের বোন থাকতো তাইলে কি আপনি ঠিক এমন ভাবেই এই পোস্ট শেয়ার দিতেন? যদি উওর হয় না! তাইলে পরের বোনের এমন টাইপের ভিডিও শেয়ার দিলেন কেন???', 'timestamp': 'Jul 9, 2020, 3:46 PM'}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
